# %%
# Imports
import sys
from pathlib import Path
from katabatic.pipeline.train_test_split.pipeline import TrainTestSplitPipeline
from katabatic.models.tabsyn.models import TabSyn

# Resolve project root and ensure it's on sys.path
ROOT = Path.cwd().resolve()
for _ in range(5):
    if (ROOT / "pyproject.toml").exists() or (ROOT / "raw_data").exists():
        break
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from utils import discretize_preprocess

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "car.csv"
output_path = ROOT / "discretized_data" / "car.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "car")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "car" / "tabsyn")

pipeline = TrainTestSplitPipeline(model=TabSyn)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/User/Documents/CapStoneA/Katabatic/raw_data/car.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/User/Documents/CapStoneA/Katabatic/discretized_data/car.csv
# Loaded data with shape: (1728, 7)
# Saved train/test full data
# Train size: (1382, 7), Test size: (346, 7)
# Train label distribution:
#  6
# 2    0.700434
# 0    0.222142
# 1    0.039797
# 3    0.037627
# Name: proportion, dtype: float64
# Test label distribution:
#  6
# 2    0.699422
# 0    0.222543
# 1    0.040462
# 3    0.037572
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (1382, 6) (1382,)
# Test shape: (346, 6) (346,)
# [TabSyn] Synthetic data saved:
#   X -> /mnt/c/Users/User/Documents/CapStoneA/Katabatic/synthetic/car/tabsyn/x_synth.csv
#   y -> /mnt/c/Users/User/Documents/CapStoneA/Katabatic/synthetic/car/tabsyn/y_synth.csv
# /home/baoduy/.cache/pypoetry/virtualenvs/katabatic-kYbufOe8-py3.11/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/baoduy/.cache/pypoetry/virtualenvs/katabatic-kYbufOe8-py3.11/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [20:01:14] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Results saved to: Results/car/tabsyn_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.0665
# F1 Score: 0.0659
#
# MLP:
# Accuracy: 0.1705
# F1 Score: 0.2081
#
# RF:
# Accuracy: 0.2283
# F1 Score: 0.2781
#
# XGBoost:
# Accuracy: 0.2428
# F1 Score: 0.2985
# Train test split pipeline executed successfully.

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "adult.csv"
output_path = ROOT / "discretized_data" / "adult.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "adult")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "adult" / "tabsyn")

pipeline = TrainTestSplitPipeline(model=TabSyn)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/User/Documents/CapStoneA/Katabatic/raw_data/adult.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/User/Documents/CapStoneA/Katabatic/discretized_data/adult.csv
# Loaded data with shape: (32561, 15)
# Saved train/test full data
# Train size: (26048, 15), Test size: (6513, 15)
# Train label distribution:
#  class
# 0    0.759175
# 1    0.240825
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.759251
# 1    0.240749
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (26048, 14) (26048,)
# Test shape: (6513, 14) (6513,)
# [TabSyn] Warning: feature count mismatch: synthetic=13 vs real=14. Leaving synthetic column names as-is.
# [TabSyn] Synthetic data saved:
#   X -> /mnt/c/Users/User/Documents/CapStoneA/Katabatic/synthetic/adult/tabsyn/x_synth.csv
#   y -> /mnt/c/Users/User/Documents/CapStoneA/Katabatic/synthetic/adult/tabsyn/y_synth.csv
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 18
#      15 synthetic_dir = str(ROOT / "synthetic" / "adult" / "tabsyn")
#      17 pipeline = TrainTestSplitPipeline(model=TabSyn)
# ---> 18 result = pipeline.run(
#      19     input_csv=input_csv,
#      20     output_dir=output_dir,
#      21     synthetic_dir=synthetic_dir,
#      22     real_test_dir=real_test_dir,
#      23 )
#      24 print(result)
#
# File /mnt/c/Users/User/Documents/CapStoneA/Katabatic/katabatic/pipeline/train_test_split/pipeline.py:46, in TrainTestSplitPipeline.run(self, *args, **kwargs)
#      44 for evaluation in self._evaluations:
#      45     eval_instance = evaluation(*args, **eval_kwargs)
# ---> 46     eval_instance.evaluate()
#      48 # Implement the specific logic for version 1 pipeline here
#      49 return "Train test split pipeline executed successfully."
#
# File /mnt/c/Users/User/Documents/CapStoneA/Katabatic/katabatic/evaluate/tstr/evaluation.py:58, in TSTREvaluation.evaluate(self)
#      56 scaler = StandardScaler()
#      57 x_train_scaled = scaler.fit_transform(self.x_train)
# ---> 58 x_test_scaled = scaler.transform(self.x_test)
#      59 model.fit(x_train_scaled, self.y_train)
#      60 y_pred = model.predict(x_test_scaled)
#
# File ~/.cache/pypoetry/virtualenvs/katabatic-kYbufOe8-py3.11/lib/python3.11/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~/.cache/pypoetry/virtualenvs/katabatic-kYbufOe8-py3.11/lib/python3.11/site-packages/sklearn/preprocessing/_data.py:1075, in StandardScaler.transform(self, X, copy)
#    1072 check_is_fitted(self)
#    1074 copy = copy if copy is not None else self.copy
# -> 1075 X = validate_data(
#    1076     self,
#    1077     X,
#    1078     reset=False,
#    1079     accept_sparse="csr",
#    1080     copy=copy,
#    1081     dtype=FLOAT_DTYPES,
#    1082     force_writeable=True,
#    1083     ensure_all_finite="allow-nan",
#    1084 )
#    1086 if sparse.issparse(X):
#    1087     if self.with_mean:
#
# File ~/.cache/pypoetry/virtualenvs/katabatic-kYbufOe8-py3.11/lib/python3.11/site-packages/sklearn/utils/validation.py:2929, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2845 def validate_data(
#    2846     _estimator,
#    2847     /,
#    (...)   2853     **check_params,
#    2854 ):
#    2855     """Validate input data and set or check feature names and counts of the input.
#    2856
#    2857     This helper function should be used in an estimator that requires input
#    (...)   2927         validated.
#    2928     """
# -> 2929     _check_feature_names(_estimator, X, reset=reset)
#    2930     tags = get_tags(_estimator)
#    2931     if y is None and tags.target_tags.required:
#
# File ~/.cache/pypoetry/virtualenvs/katabatic-kYbufOe8-py3.11/lib/python3.11/site-packages/sklearn/utils/validation.py:2787, in _check_feature_names(estimator, X, reset)
#    2784 if not missing_names and not unexpected_names:
#    2785     message += "Feature names must be in the same order as they were in fit.\n"
# -> 2787 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - age
# - capital-gain
# - capital-loss
# - education
# - education-num
# - ...
# Feature names seen at fit time, yet now missing:
# - cat_1
# - cat_2
# - cat_3
# - cat_4
# - cat_5
# - ...

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "magic.csv"
output_path = ROOT / "discretized_data" / "magic.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "magic")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "adult" / "magic")

pipeline = TrainTestSplitPipeline(model=TabSyn)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/User/Documents/CapStoneA/Katabatic/raw_data/magic.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/User/Documents/CapStoneA/Katabatic/discretized_data/magic.csv
# Loaded data with shape: (19020, 11)
# Saved train/test full data
# Train size: (15216, 11), Test size: (3804, 11)
# Train label distribution:
#  class
# 0    0.648396
# 1    0.351604
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.648265
# 1    0.351735
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (15216, 10) (15216,)
# Test shape: (3804, 10) (3804,)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 18
#      15 synthetic_dir = str(ROOT / "synthetic" / "adult" / "magic")
#      17 pipeline = TrainTestSplitPipeline(model=TabSyn)
# ---> 18 result = pipeline.run(
#      19     input_csv=input_csv,
#      20     output_dir=output_dir,
#      21     synthetic_dir=synthetic_dir,
#      22     real_test_dir=real_test_dir,
#      23 )
#      24 print(result)
#
# File /mnt/c/Users/User/Documents/CapStoneA/Katabatic/katabatic/pipeline/train_test_split/pipeline.py:38, in TrainTestSplitPipeline.run(self, *args, **kwargs)
#      35 split_dataset(input_csv, output_dir, *args, **kwargs)
#      37 # Train the model (may consume extra kwargs like 'config')
# ---> 38 current_model.train(output_dir, *args, **kwargs)
#      40 # Filter kwargs for evaluations to avoid unexpected params (e.g., 'config')
#      41 eval_kwargs = dict(kwargs)
#
# File /mnt/c/Users/User/Documents/CapStoneA/Katabatic/katabatic/models/tabsyn/models.py:81, in TabSyn.train(self, data_dir, save_dir, extra_info, *args, **kwargs)
#      79 self.check_dependencies()
#      80 # 1) fit model
# ---> 81 self.state = train_tabsyn(
#      82     data_dir=data_dir,
#      83     cfg=self.config,
#      84     save_dir=save_dir,
#      85     extra_info=extra_info or {},
#      86 )
#      87 self.is_fitted = True
#      89 # 2) Decide where to save synthetic data
#
# File /mnt/c/Users/User/Documents/CapStoneA/Katabatic/katabatic/models/tabsyn/utils.py:481, in train_tabsyn(data_dir, cfg, save_dir, extra_info)
#     478 info = _load_info(data_dir)
#     480 # ---- Load & prepare training mats
# --> 481 Xn_tr_np, Xc_tr_idx_np, y_tr, cat_sizes = _prepare_training_mats(data_dir, info)
#     482 n_num = Xn_tr_np.shape[1]
#     483 token_dim = cfg.d_token
#
# File /mnt/c/Users/User/Documents/CapStoneA/Katabatic/katabatic/models/tabsyn/utils.py:414, in _prepare_training_mats(data_dir, info)
#     410 def _prepare_training_mats(
#     411     data_dir: str,
#     412     info: Dict[str, Any],
#     413 ) -> Tuple[np.ndarray, Optional[np.ndarray], np.ndarray, List[int]]:
# --> 414     Xn_tr, Xc_tr, y_tr = _load_split_arrays(data_dir, "train")
#     415     task_type = info.get("task_type", "binclass")
#     416     Xn_tr, Xc_tr = _concat_xy(Xn_tr, Xc_tr, y_tr, task_type)
#
# File /mnt/c/Users/User/Documents/CapStoneA/Katabatic/katabatic/models/tabsyn/utils.py:102, in _load_split_arrays(data_dir, split)
#     100 Xn = _maybe(f"X_num_{split}.npy")
#     101 Xc = _maybe(f"X_cat_{split}.npy")
# --> 102 y = np.load(os.path.join(data_dir, f"y_{split}.npy"), allow_pickle=True)
#     103 return Xn, Xc, y
#
# File ~/.cache/pypoetry/virtualenvs/katabatic-kYbufOe8-py3.11/lib/python3.11/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/c/Users/User/Documents/CapStoneA/Katabatic/sample_data/magic/y_train.npy'

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "nursery.csv"
output_path = ROOT / "discretized_data" / "nursery.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "nursery")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "nursery" / "tabsyn")

pipeline = TrainTestSplitPipeline(model=TabSyn)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/User/Documents/CapStoneA/Katabatic/raw_data/nursery.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/User/Documents/CapStoneA/Katabatic/discretized_data/nursery.csv
# Loaded data with shape: (12960, 9)
# Saved train/test full data
# Train size: (10368, 9), Test size: (2592, 9)
# Train label distribution:
#  8
# 0    0.333333
# 1    0.329186
# 3    0.312018
# 4    0.025270
# 2    0.000193
# Name: proportion, dtype: float64
# Test label distribution:
#  8
# 0    0.333333
# 1    0.329090
# 3    0.312114
# 4    0.025463
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (10368, 8) (10368,)
# Test shape: (2592, 8) (2592,)
# [TabSyn] Synthetic data saved:
#   X -> /mnt/c/Users/User/Documents/CapStoneA/Katabatic/synthetic/nursery/tabsyn/x_synth.csv
#   y -> /mnt/c/Users/User/Documents/CapStoneA/Katabatic/synthetic/nursery/tabsyn/y_synth.csv
# /home/baoduy/.cache/pypoetry/virtualenvs/katabatic-kYbufOe8-py3.11/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 18
#      15 synthetic_dir = str(ROOT / "synthetic" / "nursery" / "tabsyn")
#      17 pipeline = TrainTestSplitPipeline(model=TabSyn)
# ---> 18 result = pipeline.run(
#      19     input_csv=input_csv,
#      20     output_dir=output_dir,
#      21     synthetic_dir=synthetic_dir,
#      22     real_test_dir=real_test_dir,
#      23 )
#      24 print(result)
#
# File /mnt/c/Users/User/Documents/CapStoneA/Katabatic/katabatic/pipeline/train_test_split/pipeline.py:46, in TrainTestSplitPipeline.run(self, *args, **kwargs)
#      44 for evaluation in self._evaluations:
#      45     eval_instance = evaluation(*args, **eval_kwargs)
# ---> 46     eval_instance.evaluate()
#      48 # Implement the specific logic for version 1 pipeline here
#      49 return "Train test split pipeline executed successfully."
#
# File /mnt/c/Users/User/Documents/CapStoneA/Katabatic/katabatic/evaluate/tstr/evaluation.py:63, in TSTREvaluation.evaluate(self)
#      61     y_prob = model.predict_proba(x_test_scaled)[:, 1]
#      62 else:
# ---> 63     model.fit(self.x_train, self.y_train)
#      64     y_pred = model.predict(self.x_test)
#      65     y_prob = model.predict_proba(self.x_test)[:, 1]
#
# File ~/.cache/pypoetry/virtualenvs/katabatic-kYbufOe8-py3.11/lib/python3.11/site-packages/xgboost/core.py:774, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     772 for k, arg in zip(sig.parameters, args):
#     773     kwargs[k] = arg
# --> 774 return func(**kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/katabatic-kYbufOe8-py3.11/lib/python3.11/site-packages/xgboost/sklearn.py:1761, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1756     expected_classes = self.classes_
#    1757 if (
#    1758     classes.shape != expected_classes.shape
#    1759     or not (classes == expected_classes).all()
#    1760 ):
# -> 1761     raise ValueError(
#    1762         f"Invalid classes inferred from unique values of `y`.  "
#    1763         f"Expected: {expected_classes}, got {classes}"
#    1764     )
#    1766 params = self.get_xgb_params()
#    1768 if callable(self.objective):
#
# ValueError: Invalid classes inferred from unique values of `y`.  Expected: [0 1 2], got [0 1 3]
