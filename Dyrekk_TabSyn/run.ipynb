# %%
# Imports
import sys
from pathlib import Path
from katabatic.pipeline.train_test_split.pipeline import TrainTestSplitPipeline
from src.tabsyn import TabSyn

# Resolve project root and ensure it's on sys.path
ROOT = Path.cwd().resolve()
for _ in range(5):
    if (ROOT / "pyproject.toml").exists() or (ROOT / "raw_data").exists():
        break
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from utils import discretize_preprocess

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "car.csv"
output_path = ROOT / "discretized_data" / "car.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "car")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "car" / "tabsyn")

pipeline = TrainTestSplitPipeline(model=TabSyn)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
    batch_size=64,
    d_token = 32,               
    n_layers_vae = 3,  
    hid_dim_vae = 64,
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/User/Documents/CapStoneA/Katabatic/raw_data/car.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/User/Documents/CapStoneA/Katabatic/discretized_data/car.csv
# [TabSyn] Initialization parameters:
#   epochs_vae: 200
#   epochs_diffusion: 500
#   batch_size: 64
#   vae_lr: 0.001
#   diffusion_lr: 0.001
#   device: cuda
#   d_token: 32
#   n_layers_vae: 3
#   hid_dim_vae: 64
#   num_timesteps: 1000
#   cat_loss_weight: 1.0
#   num_loss_weight: 1.0
# Loaded data with shape: (1728, 7)
# Saved train/test full data
# Train size: (1382, 7), Test size: (346, 7)
# Train label distribution:
#  6
# 2    0.700434
# 0    0.222142
# 1    0.039797
# 3    0.037627
# Name: proportion, dtype: float64
# Test label distribution:
#  6
# 2    0.699422
# 0    0.222543
# 1    0.040462
# 3    0.037572
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (1382, 6) (1382,)
# Test shape: (346, 6) (346,)
# [TabSyn] Loading training data from /mnt/c/Users/User/Documents/CapStoneA/Katabatic/sample_data/car/train_full.csv...
# [TabSyn] Found 0 numerical and 6 categorical features.
# [TabSyn] Target column: '6'
# [TabSyn] Target distribution: {0: 307, 1: 55, 2: 968, 3: 52}
#
# [TabSyn] Phase 1: Training Conditional VAE...
# Epoch 20/200 | Recon: 0.0804 (Num: 0.0000, Cat: 0.0804) | KL: 45.6077 | Beta: 0.001900
# Epoch 40/200 | Recon: 0.0470 (Num: 0.0000, Cat: 0.0470) | KL: 22.7154 | Beta: 0.003900
# Epoch 60/200 | Recon: 0.0311 (Num: 0.0000, Cat: 0.0311) | KL: 16.2913 | Beta: 0.005900
# Epoch 80/200 | Recon: 0.0519 (Num: 0.0000, Cat: 0.0519) | KL: 12.2661 | Beta: 0.007900
# Epoch 100/200 | Recon: 0.0445 (Num: 0.0000, Cat: 0.0445) | KL: 10.9574 | Beta: 0.009900
# Epoch 120/200 | Recon: 0.0627 (Num: 0.0000, Cat: 0.0627) | KL: 9.3855 | Beta: 0.010000
# Epoch 140/200 | Recon: 0.0279 (Num: 0.0000, Cat: 0.0279) | KL: 9.1061 | Beta: 0.010000
# Epoch 160/200 | Recon: 0.0467 (Num: 0.0000, Cat: 0.0467) | KL: 8.5223 | Beta: 0.010000
# Epoch 180/200 | Recon: 0.0403 (Num: 0.0000, Cat: 0.0403) | KL: 8.6689 | Beta: 0.010000
# Epoch 200/200 | Recon: 0.0152 (Num: 0.0000, Cat: 0.0152) | KL: 8.2054 | Beta: 0.010000
# [TabSyn] VAE training completed!
#
# [TabSyn] Extracting latent embeddings...
#
# [TabSyn] Phase 2: Training Diffusion Model...
# Epoch 50/500 | Loss: 0.1681
# Epoch 100/500 | Loss: 0.1727
# Epoch 150/500 | Loss: 0.1648
# Epoch 200/500 | Loss: 0.1523
# Epoch 250/500 | Loss: 0.1438
# Epoch 300/500 | Loss: 0.1285
# Epoch 350/500 | Loss: 0.1229
# Epoch 400/500 | Loss: 0.1240
# Epoch 450/500 | Loss: 0.1161
# Epoch 500/500 | Loss: 0.1044
# [TabSyn] Sampling 1382 rows (Conditionally)...
#
# [TabSyn] Target '6' distribution check:
#   Synthetic: {0: 325, 1: 58, 2: 943, 3: 56}
# [TabSyn] Saved synthetic data.
# /home/baoduy/.cache/pypoetry/virtualenvs/katabatic-kYbufOe8-py3.11/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/baoduy/.cache/pypoetry/virtualenvs/katabatic-kYbufOe8-py3.11/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [21:26:49] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Results saved to: Results/car/tabsyn_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.6994
# F1 Score: 0.5757
#
# MLP:
# Accuracy: 0.6994
# F1 Score: 0.5757
#
# RF:
# Accuracy: 0.6012
# F1 Score: 0.5586
#
# XGBoost:
# Accuracy: 0.6040
# F1 Score: 0.5755
# Train test split pipeline executed successfully.

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "adult.csv"
output_path = ROOT / "discretized_data" / "adult.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "adult")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "adult" / "tabsyn")

pipeline = TrainTestSplitPipeline(model=TabSyn)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
    batch_size=1024,
    d_token = 32,               
    n_layers_vae = 3,  
    hid_dim_vae = 64,
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/User/Documents/CapStoneA/Katabatic/raw_data/adult.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/User/Documents/CapStoneA/Katabatic/discretized_data/adult.csv
# [TabSyn] Initialization parameters:
#   epochs_vae: 200
#   epochs_diffusion: 500
#   batch_size: 1024
#   vae_lr: 0.001
#   diffusion_lr: 0.001
#   device: cuda
#   d_token: 128
#   n_layers_vae: 5
#   hid_dim_vae: 128
#   num_timesteps: 1000
#   cat_loss_weight: 1.0
#   num_loss_weight: 1.0
# Loaded data with shape: (32561, 15)
# Saved train/test full data
# Train size: (26048, 15), Test size: (6513, 15)
# Train label distribution:
#  class
# 0    0.759175
# 1    0.240825
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.759251
# 1    0.240749
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (26048, 14) (26048,)
# Test shape: (6513, 14) (6513,)
# [TabSyn] Loading training data from /mnt/c/Users/User/Documents/CapStoneA/Katabatic/sample_data/adult/train_full.csv...
# [TabSyn] Found 0 numerical and 14 categorical features.
# [TabSyn] Target column: 'class'
# [TabSyn] Target distribution: {0: 19775, 1: 6273}
#
# [TabSyn] Phase 1: Training Conditional VAE...
# Epoch 20/200 | Recon: 0.1490 (Num: 0.0000, Cat: 0.1490) | KL: 95.0478 | Beta: 0.001900

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "magic.csv"
output_path = ROOT / "discretized_data" / "magic.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "magic")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "magic" / "tabsyn")

pipeline = TrainTestSplitPipeline(model=TabSyn)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
    batch_size=1024,
    d_token = 128,               
    n_layers_vae = 5,  
    hid_dim_vae = 128,
)
print(result)

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "nursery.csv"
output_path = ROOT / "discretized_data" / "nursery.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "nursery")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "nursery" / "tabsyn")

pipeline = TrainTestSplitPipeline(model=TabSyn)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
    batch_size=128,
    d_token = 32,               
    n_layers_vae = 3,  
    hid_dim_vae = 64,
)
print(result)

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "shuttle.csv"
output_path = ROOT / "discretized_data" / "shuttle.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "shuttle")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "shuttle" / "tabsyn")

pipeline = TrainTestSplitPipeline(model=TabSyn)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
    batch_size=128,
    d_token = 32,               
    n_layers_vae = 3,  
    hid_dim_vae = 64,
)
print(result)
