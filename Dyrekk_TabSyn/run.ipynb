# %%
# Imports
import sys
from pathlib import Path
from katabatic.pipeline.train_test_split.pipeline import TrainTestSplitPipeline
from src.tabsyn import TabSyn

# Resolve project root and ensure it's on sys.path
ROOT = Path.cwd().resolve()
for _ in range(5):
    if (ROOT / "pyproject.toml").exists() or (ROOT / "raw_data").exists():
        break
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from utils import discretize_preprocess

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "car.csv"
output_path = ROOT / "discretized_data" / "car.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "car")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "car" / "tabsyn")

pipeline = TrainTestSplitPipeline(model=TabSyn)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
    batch_size=64,
    d_token = 32,               
    n_layers_vae = 3,  
    hid_dim_vae = 64,
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/raw_data/car.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/discretized_data/car.csv
# Loaded data with shape: (1728, 7)
# Saved train/test full data
# Train size: (1382, 7), Test size: (346, 7)
# Train label distribution:
#  6
# 2    0.700434
# 0    0.222142
# 1    0.039797
# 3    0.037627
# Name: proportion, dtype: float64
# Test label distribution:
#  6
# 2    0.699422
# 0    0.222543
# 1    0.040462
# 3    0.037572
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (1382, 6) (1382,)
# Test shape: (346, 6) (346,)
# [TabSyn] Loading training data from /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/sample_data/car/train_full.csv...
# [TabSyn] Found 0 numerical and 7 categorical columns (target='6')
#
# [TabSyn] Phase 1: Training VAE...
# Epoch 5/50 | Recon: 23.6042 (Num: 0.0000, Cat: 7.8681) | KL: 23.4904 | Beta: 0.001280
# Epoch 10/50 | Recon: 19.7276 (Num: 0.0000, Cat: 6.5759) | KL: 41.0784 | Beta: 0.002880
# Epoch 15/50 | Recon: 17.0570 (Num: 0.0000, Cat: 5.6857) | KL: 53.0210 | Beta: 0.004480
# Epoch 20/50 | Recon: 14.9554 (Num: 0.0000, Cat: 4.9851) | KL: 55.6121 | Beta: 0.006080
# Epoch 25/50 | Recon: 12.9222 (Num: 0.0000, Cat: 4.3074) | KL: 51.3391 | Beta: 0.007680
# Epoch 30/50 | Recon: 11.4330 (Num: 0.0000, Cat: 3.8110) | KL: 50.3870 | Beta: 0.008000
# Epoch 35/50 | Recon: 10.2509 (Num: 0.0000, Cat: 3.4170) | KL: 51.1133 | Beta: 0.008000
# Epoch 40/50 | Recon: 9.3166 (Num: 0.0000, Cat: 3.1055) | KL: 52.6231 | Beta: 0.008000
# Epoch 45/50 | Recon: 8.8452 (Num: 0.0000, Cat: 2.9484) | KL: 52.4392 | Beta: 0.008000
# Epoch 50/50 | Recon: 8.4033 (Num: 0.0000, Cat: 2.8011) | KL: 52.0323 | Beta: 0.008000
# [TabSyn] VAE training completed!
#
# [TabSyn] Extracting latent embeddings...
# [TabSyn] Latent embeddings shape: torch.Size([1382, 448])
# [TabSyn] Latent stats - mean: 0.0000, std: 0.9996
#
# [TabSyn] Phase 2: Training Diffusion Model...
# Epoch 5/50 | Loss: 0.8930
# Epoch 10/50 | Loss: 0.7732
# Epoch 15/50 | Loss: 0.6971
# Epoch 20/50 | Loss: 0.6316
# Epoch 25/50 | Loss: 0.5965
# Epoch 30/50 | Loss: 0.5709
# Epoch 35/50 | Loss: 0.5518
# Epoch 40/50 | Loss: 0.5356
# Epoch 45/50 | Loss: 0.5290
# Epoch 50/50 | Loss: 0.5168
# [TabSyn] Diffusion training completed!
# [TabSyn] Auto-generating 1382 synthetic samples in /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/synthetic/car/tabsyn ...
# [TabSyn] Sampling 1382 rows...
#
# [TabSyn] Target column '6' distribution:
#   Synthetic: {0: 538, 1: 116, 2: 422, 3: 306}
#   Original:  {0: 307, 1: 55, 2: 968, 3: 52}
#
# [TabSyn] Synthetic data saved:
#   X -> /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/synthetic/car/tabsyn/x_synth.csv
#   y -> /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/synthetic/car/tabsyn/y_synth.csv
# /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:780: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [18:30:59] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Results saved to: Results/car/tabsyn_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.5751
# F1 Score: 0.5829
#
# MLP:
# Accuracy: 0.5260
# F1 Score: 0.5541
#
# RF:
# Accuracy: 0.4393
# F1 Score: 0.4925
#
# XGBoost:
# Accuracy: 0.3960
# F1 Score: 0.4551
# Train test split pipeline executed successfully.

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "adult.csv"
output_path = ROOT / "discretized_data" / "adult.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "adult")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "adult" / "tabsyn")

pipeline = TrainTestSplitPipeline(model=TabSyn)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
    batch_size=512,
    d_token = 64,               
    n_layers_vae = 4,  
    hid_dim_vae = 128,
    diffusion_lr=2e-3
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/raw_data/adult.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/discretized_data/adult.csv
# Loaded data with shape: (32561, 15)
# Saved train/test full data
# Train size: (26048, 15), Test size: (6513, 15)
# Train label distribution:
#  class
# 0    0.759175
# 1    0.240825
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.759251
# 1    0.240749
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (26048, 14) (26048,)
# Test shape: (6513, 14) (6513,)
# [TabSyn] Loading training data from /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/sample_data/adult/train_full.csv...
# [TabSyn] Found 0 numerical and 15 categorical columns (target='class')
#
# [TabSyn] Phase 1: Training VAE...
# Epoch 5/50 | Recon: 45.6389 (Num: 0.0000, Cat: 15.2130) | KL: 100.5211 | Beta: 0.001280
# Epoch 10/50 | Recon: 16.7063 (Num: 0.0000, Cat: 5.5688) | KL: 133.1714 | Beta: 0.002880
# Epoch 15/50 | Recon: 4.9010 (Num: 0.0000, Cat: 1.6337) | KL: 130.8192 | Beta: 0.004480
# Epoch 20/50 | Recon: 2.4724 (Num: 0.0000, Cat: 0.8241) | KL: 103.9005 | Beta: 0.006080
# Epoch 25/50 | Recon: 1.6838 (Num: 0.0000, Cat: 0.5613) | KL: 79.2330 | Beta: 0.007680
# Epoch 30/50 | Recon: 1.1621 (Num: 0.0000, Cat: 0.3874) | KL: 64.5884 | Beta: 0.008000
# Epoch 35/50 | Recon: 0.9114 (Num: 0.0000, Cat: 0.3038) | KL: 56.6948 | Beta: 0.008000
# Epoch 40/50 | Recon: 0.6212 (Num: 0.0000, Cat: 0.2071) | KL: 51.9341 | Beta: 0.008000
# Epoch 45/50 | Recon: 0.7182 (Num: 0.0000, Cat: 0.2394) | KL: 48.3473 | Beta: 0.008000
# Epoch 50/50 | Recon: 0.5675 (Num: 0.0000, Cat: 0.1892) | KL: 46.9438 | Beta: 0.008000
# [TabSyn] VAE training completed!
#
# [TabSyn] Extracting latent embeddings...
# [TabSyn] Latent embeddings shape: torch.Size([26048, 960])
# [TabSyn] Latent stats - mean: 0.0000, std: 1.0000
#
# [TabSyn] Phase 2: Training Diffusion Model...
# Epoch 5/50 | Loss: 0.6490
# Epoch 10/50 | Loss: 0.5581
# Epoch 15/50 | Loss: 0.5427
# Epoch 20/50 | Loss: 0.5325
# Epoch 25/50 | Loss: 0.5249
# Epoch 30/50 | Loss: 0.5199
# Epoch 35/50 | Loss: 0.5170
# Epoch 40/50 | Loss: 0.5132
# Epoch 45/50 | Loss: 0.5115
# Epoch 50/50 | Loss: 0.5114
# [TabSyn] Diffusion training completed!
# [TabSyn] Auto-generating 26048 synthetic samples in /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/synthetic/adult/tabsyn ...
# [TabSyn] Sampling 26048 rows...
#
# [TabSyn] Target column 'class' distribution:
#   Synthetic: {0: 17139, 1: 8909}
#   Original:  {0: 19775, 1: 6273}
#
# [TabSyn] Synthetic data saved:
#   X -> /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/synthetic/adult/tabsyn/x_synth.csv
#   y -> /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/synthetic/adult/tabsyn/y_synth.csv
# /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:780: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Results saved to: Results/adult/tabsyn_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.7593
# F1 Score: 0.6553
# AUC: 0.6967
#
# MLP:
# Accuracy: 0.6809
# F1 Score: 0.6553
# AUC: 0.5444
#
# RF:
# Accuracy: 0.7508
# F1 Score: 0.6805
# AUC: 0.6052
#
# XGBoost:
# Accuracy: 0.4711
# F1 Score: 0.4893
# AUC: 0.6428
# Train test split pipeline executed successfully.

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "magic.csv"
output_path = ROOT / "discretized_data" / "magic.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "magic")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "magic" / "tabsyn")

pipeline = TrainTestSplitPipeline(model=TabSyn)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
    batch_size=512,
    d_token = 32,               
    n_layers_vae = 4,  
    hid_dim_vae = 64,
    diffusion_lr=2e-3
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/raw_data/magic.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/discretized_data/magic.csv
# Loaded data with shape: (19020, 11)
# Saved train/test full data
# Train size: (15216, 11), Test size: (3804, 11)
# Train label distribution:
#  class
# 0    0.648396
# 1    0.351604
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.648265
# 1    0.351735
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (15216, 10) (15216,)
# Test shape: (3804, 10) (3804,)
# [TabSyn] Loading training data from /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/sample_data/magic/train_full.csv...
# [TabSyn] Found 0 numerical and 11 categorical columns (target='class')
#
# [TabSyn] Phase 1: Training VAE...
# Epoch 5/50 | Recon: 31.8424 (Num: 0.0000, Cat: 10.6141) | KL: 115.9921 | Beta: 0.001280
# Epoch 10/50 | Recon: 13.1910 (Num: 0.0000, Cat: 4.3970) | KL: 138.8347 | Beta: 0.002880
# Epoch 15/50 | Recon: 4.2099 (Num: 0.0000, Cat: 1.4033) | KL: 129.6228 | Beta: 0.004480
# Epoch 20/50 | Recon: 2.1688 (Num: 0.0000, Cat: 0.7229) | KL: 103.0492 | Beta: 0.006080
# Epoch 25/50 | Recon: 1.4466 (Num: 0.0000, Cat: 0.4822) | KL: 78.9778 | Beta: 0.007680
# Epoch 30/50 | Recon: 1.2587 (Num: 0.0000, Cat: 0.4196) | KL: 66.3966 | Beta: 0.008000
# Epoch 35/50 | Recon: 0.9043 (Num: 0.0000, Cat: 0.3014) | KL: 59.8024 | Beta: 0.008000
# Epoch 40/50 | Recon: 0.8695 (Num: 0.0000, Cat: 0.2898) | KL: 56.5893 | Beta: 0.008000
# Epoch 45/50 | Recon: 0.7738 (Num: 0.0000, Cat: 0.2579) | KL: 53.4240 | Beta: 0.008000
# Epoch 50/50 | Recon: 0.8478 (Num: 0.0000, Cat: 0.2826) | KL: 51.9090 | Beta: 0.008000
# [TabSyn] VAE training completed!
#
# [TabSyn] Extracting latent embeddings...
# [TabSyn] Latent embeddings shape: torch.Size([15216, 704])
# [TabSyn] Latent stats - mean: -0.0000, std: 1.0000
#
# [TabSyn] Phase 2: Training Diffusion Model...
# Epoch 5/50 | Loss: 0.6355
# Epoch 10/50 | Loss: 0.5142
# Epoch 15/50 | Loss: 0.4393
# Epoch 20/50 | Loss: 0.3967
# Epoch 25/50 | Loss: 0.3830
# Epoch 30/50 | Loss: 0.3722
# Epoch 35/50 | Loss: 0.3669
# Epoch 40/50 | Loss: 0.3626
# Epoch 45/50 | Loss: 0.3576
# Epoch 50/50 | Loss: 0.3587
# [TabSyn] Diffusion training completed!
# [TabSyn] Auto-generating 15216 synthetic samples in /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/synthetic/magic/tabsyn ...
# [TabSyn] Sampling 15216 rows...
#
# [TabSyn] Target column 'class' distribution:
#   Synthetic: {0: 6463, 1: 8753}
#   Original:  {0: 9866, 1: 5350}
#
# [TabSyn] Synthetic data saved:
#   X -> /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/synthetic/magic/tabsyn/x_synth.csv
#   y -> /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/synthetic/magic/tabsyn/y_synth.csv
# /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:780: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Results saved to: Results/magic/tabsyn_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.3517
# F1 Score: 0.1830
# AUC: 0.7877
#
# MLP:
# Accuracy: 0.4232
# F1 Score: 0.3793
# AUC: 0.6572
#
# RF:
# Accuracy: 0.4479
# F1 Score: 0.4180
# AUC: 0.5925
#
# XGBoost:
# Accuracy: 0.5733
# F1 Score: 0.5824
# AUC: 0.5753
# Train test split pipeline executed successfully.

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "nursery.csv"
output_path = ROOT / "discretized_data" / "nursery.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "nursery")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "nursery" / "tabsyn")

pipeline = TrainTestSplitPipeline(model=TabSyn)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
    batch_size=256,
    d_token =32,               
    n_layers_vae = 4,  
    hid_dim_vae = 64,
    diffusion_lr=2e-3
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/raw_data/nursery.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/discretized_data/nursery.csv
# Loaded data with shape: (12960, 9)
# Saved train/test full data
# Train size: (10368, 9), Test size: (2592, 9)
# Train label distribution:
#  8
# 0    0.333333
# 1    0.329186
# 3    0.312018
# 4    0.025270
# 2    0.000193
# Name: proportion, dtype: float64
# Test label distribution:
#  8
# 0    0.333333
# 1    0.329090
# 3    0.312114
# 4    0.025463
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (10368, 8) (10368,)
# Test shape: (2592, 8) (2592,)
# [TabSyn] Loading training data from /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/sample_data/nursery/train_full.csv...
# [TabSyn] Found 0 numerical and 9 categorical columns (target='8')
#
# [TabSyn] Phase 1: Training VAE...
# Epoch 5/50 | Recon: 18.0033 (Num: 0.0000, Cat: 6.0011) | KL: 69.9937 | Beta: 0.001280
# Epoch 10/50 | Recon: 2.5227 (Num: 0.0000, Cat: 0.8409) | KL: 84.8843 | Beta: 0.002880
# Epoch 15/50 | Recon: 0.5891 (Num: 0.0000, Cat: 0.1964) | KL: 71.6527 | Beta: 0.004480
# Epoch 20/50 | Recon: 0.5548 (Num: 0.0000, Cat: 0.1849) | KL: 51.0926 | Beta: 0.006080
# Epoch 25/50 | Recon: 0.1685 (Num: 0.0000, Cat: 0.0562) | KL: 37.3802 | Beta: 0.007680
# Epoch 30/50 | Recon: 0.1443 (Num: 0.0000, Cat: 0.0481) | KL: 30.1298 | Beta: 0.008000
# Epoch 35/50 | Recon: 0.0964 (Num: 0.0000, Cat: 0.0321) | KL: 25.8456 | Beta: 0.008000
# Epoch 40/50 | Recon: 0.1092 (Num: 0.0000, Cat: 0.0364) | KL: 24.6410 | Beta: 0.008000
# Epoch 45/50 | Recon: 0.0796 (Num: 0.0000, Cat: 0.0265) | KL: 23.2406 | Beta: 0.008000
# Epoch 50/50 | Recon: 0.0823 (Num: 0.0000, Cat: 0.0274) | KL: 23.1496 | Beta: 0.008000
# [TabSyn] VAE training completed!
#
# [TabSyn] Extracting latent embeddings...
# [TabSyn] Latent embeddings shape: torch.Size([10368, 576])
# [TabSyn] Latent stats - mean: -0.0000, std: 1.0000
#
# [TabSyn] Phase 2: Training Diffusion Model...
# Epoch 5/50 | Loss: 0.6415
# Epoch 10/50 | Loss: 0.5105
# Epoch 15/50 | Loss: 0.4370
# Epoch 20/50 | Loss: 0.3841
# Epoch 25/50 | Loss: 0.3441
# Epoch 30/50 | Loss: 0.3121
# Epoch 35/50 | Loss: 0.2965
# Epoch 40/50 | Loss: 0.2822
# Epoch 45/50 | Loss: 0.2735
# Epoch 50/50 | Loss: 0.2697
# [TabSyn] Diffusion training completed!
# [TabSyn] Auto-generating 10368 synthetic samples in /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/synthetic/nursery/tabsyn ...
# [TabSyn] Sampling 10368 rows...
#
# [TabSyn] Target column '8' distribution:
#   Synthetic: {0: 1070, 1: 3230, 2: 763, 3: 3554, 4: 1751}
#   Original:  {0: 3456, 1: 3413, 2: 2, 3: 3235, 4: 262}
#
# [TabSyn] Synthetic data saved:
#   X -> /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/synthetic/nursery/tabsyn/x_synth.csv
#   y -> /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/synthetic/nursery/tabsyn/y_synth.csv
# /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:780: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [18:42:55] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Results saved to: Results/nursery/tabsyn_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.3642
# F1 Score: 0.2930
#
# MLP:
# Accuracy: 0.3962
# F1 Score: 0.3374
#
# RF:
# Accuracy: 0.3225
# F1 Score: 0.3345
#
# XGBoost:
# Accuracy: 0.3777
# F1 Score: 0.3728
# Train test split pipeline executed successfully.

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "shuttle.csv"
output_path = ROOT / "discretized_data" / "shuttle.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "shuttle")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "shuttle" / "tabsyn")

pipeline = TrainTestSplitPipeline(model=TabSyn)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
    batch_size=512,
    d_token = 32,               
    n_layers_vae = 4,  
    hid_dim_vae = 64,
    diffusion_lr=2e-3
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/raw_data/shuttle.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/discretized_data/shuttle.csv
# Loaded data with shape: (58000, 10)
# Saved train/test full data
# Train size: (46400, 10), Test size: (11600, 10)
# Train label distribution:
#  class
# 0    0.785970
# 3    0.153491
# 4    0.056336
# 2    0.002953
# 1    0.000862
# 6    0.000216
# 5    0.000172
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.785948
# 3    0.153534
# 4    0.056293
# 2    0.002931
# 1    0.000862
# 6    0.000259
# 5    0.000172
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (46400, 9) (46400,)
# Test shape: (11600, 9) (11600,)
# [TabSyn] Loading training data from /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/sample_data/shuttle/train_full.csv...
# [TabSyn] Found 0 numerical and 10 categorical columns (target='class')
#
# [TabSyn] Phase 1: Training VAE...
# Epoch 5/50 | Recon: 8.9210 (Num: 0.0000, Cat: 2.9737) | KL: 178.2066 | Beta: 0.001280
# Epoch 10/50 | Recon: 1.7331 (Num: 0.0000, Cat: 0.5777) | KL: 125.6046 | Beta: 0.002880
# Epoch 15/50 | Recon: 0.5009 (Num: 0.0000, Cat: 0.1670) | KL: 70.9439 | Beta: 0.004480
# Epoch 20/50 | Recon: 0.4274 (Num: 0.0000, Cat: 0.1425) | KL: 46.7777 | Beta: 0.006080
# Epoch 25/50 | Recon: 0.3164 (Num: 0.0000, Cat: 0.1055) | KL: 34.8741 | Beta: 0.007680
# Epoch 30/50 | Recon: 0.1971 (Num: 0.0000, Cat: 0.0657) | KL: 28.1069 | Beta: 0.008000
# Epoch 35/50 | Recon: 0.1077 (Num: 0.0000, Cat: 0.0359) | KL: 25.0265 | Beta: 0.008000
# Epoch 40/50 | Recon: 0.1547 (Num: 0.0000, Cat: 0.0516) | KL: 23.0459 | Beta: 0.008000
# Epoch 45/50 | Recon: 0.1077 (Num: 0.0000, Cat: 0.0359) | KL: 21.5458 | Beta: 0.008000
# Epoch 50/50 | Recon: 0.2038 (Num: 0.0000, Cat: 0.0679) | KL: 20.8634 | Beta: 0.008000
# [TabSyn] VAE training completed!
#
# [TabSyn] Extracting latent embeddings...
# [TabSyn] Latent embeddings shape: torch.Size([46400, 640])
# [TabSyn] Latent stats - mean: 0.0000, std: 1.0000
#
# [TabSyn] Phase 2: Training Diffusion Model...
# Epoch 5/50 | Loss: 0.3908
# Epoch 10/50 | Loss: 0.2951
# Epoch 15/50 | Loss: 0.2744
# Epoch 20/50 | Loss: 0.2669
# Epoch 25/50 | Loss: 0.2615
# Epoch 30/50 | Loss: 0.2566
# Epoch 35/50 | Loss: 0.2525
# Epoch 40/50 | Loss: 0.2501
# Epoch 45/50 | Loss: 0.2481
# Epoch 50/50 | Loss: 0.2466
# [TabSyn] Diffusion training completed!
# [TabSyn] Auto-generating 46400 synthetic samples in /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/synthetic/shuttle/tabsyn ...
# [TabSyn] Sampling 46400 rows...
#
# [TabSyn] Target column 'class' distribution:
#   Synthetic: {0: 7398, 1: 6609, 2: 4973, 3: 8014, 4: 11783, 5: 5251, 6: 2372}
#   Original:  {0: 36469, 1: 40, 2: 137, 3: 7122, 4: 2614, 5: 8, 6: 10}
#
# [TabSyn] Synthetic data saved:
#   X -> /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/synthetic/shuttle/tabsyn/x_synth.csv
#   y -> /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/synthetic/shuttle/tabsyn/y_synth.csv
# /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [18:48:10] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Results saved to: Results/shuttle/tabsyn_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.6770
# F1 Score: 0.7114
#
# MLP:
# Accuracy: 0.6038
# F1 Score: 0.6689
#
# RF:
# Accuracy: 0.3230
# F1 Score: 0.3893
#
# XGBoost:
# Accuracy: 0.4461
# F1 Score: 0.5206
# Train test split pipeline executed successfully.
