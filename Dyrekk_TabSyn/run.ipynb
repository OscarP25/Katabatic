# %%
# Imports
import sys
from pathlib import Path
from katabatic.pipeline.train_test_split.pipeline import TrainTestSplitPipeline
from src.tabsyn import TabSyn

# Resolve project root and ensure it's on sys.path
ROOT = Path.cwd().resolve()
for _ in range(5):
    if (ROOT / "pyproject.toml").exists() or (ROOT / "raw_data").exists():
        break
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from utils import discretize_preprocess

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "car.csv"
output_path = ROOT / "discretized_data" / "car.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "car")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "car" / "tabsyn")

pipeline = TrainTestSplitPipeline(model=TabSyn)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
    batch_size=64,
    d_token = 32,               
    n_layers_vae = 3,  
    hid_dim_vae = 64,
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/User/Documents/CapStoneA/Katabatic/raw_data/car.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/User/Documents/CapStoneA/Katabatic/discretized_data/car.csv
# Loaded data with shape: (1728, 7)
# Saved train/test full data
# Train size: (1382, 7), Test size: (346, 7)
# Train label distribution:
#  6
# 2    0.700434
# 0    0.222142
# 1    0.039797
# 3    0.037627
# Name: proportion, dtype: float64
# Test label distribution:
#  6
# 2    0.699422
# 0    0.222543
# 1    0.040462
# 3    0.037572
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (1382, 6) (1382,)
# Test shape: (346, 6) (346,)
# [TabSyn] Loading training data from /mnt/c/Users/User/Documents/CapStoneA/Katabatic/sample_data/car/train_full.csv...
# [TabSyn] Found 0 numerical and 7 categorical columns (target='6')
#
# [TabSyn] Phase 1: Training VAE...
# Epoch 10/100 | Recon: 0.8557 (Num: 0.0000, Cat: 0.4278) | KL: 95.5014 | Beta: 0.001440
# Epoch 20/100 | Recon: 0.3376 (Num: 0.0000, Cat: 0.1688) | KL: 63.9749 | Beta: 0.003040
# Epoch 30/100 | Recon: 0.2553 (Num: 0.0000, Cat: 0.1276) | KL: 41.5831 | Beta: 0.004640
# Epoch 40/100 | Recon: 0.1583 (Num: 0.0000, Cat: 0.0791) | KL: 28.4926 | Beta: 0.006240
# Epoch 50/100 | Recon: 0.2008 (Num: 0.0000, Cat: 0.1004) | KL: 23.9367 | Beta: 0.007840
# Epoch 60/100 | Recon: 0.1213 (Num: 0.0000, Cat: 0.0607) | KL: 18.1716 | Beta: 0.008000
# Epoch 70/100 | Recon: 0.1001 (Num: 0.0000, Cat: 0.0501) | KL: 16.5606 | Beta: 0.008000
# Epoch 80/100 | Recon: 0.1526 (Num: 0.0000, Cat: 0.0763) | KL: 14.6322 | Beta: 0.008000
# Epoch 90/100 | Recon: 0.0864 (Num: 0.0000, Cat: 0.0432) | KL: 14.6927 | Beta: 0.008000
# Epoch 100/100 | Recon: 0.0772 (Num: 0.0000, Cat: 0.0386) | KL: 14.3799 | Beta: 0.008000
# [TabSyn] VAE training completed!
#
# [TabSyn] Extracting latent embeddings...
# [TabSyn] Latent embeddings shape: torch.Size([1382, 448])
# [TabSyn] Latent stats - mean: 0.0000, std: 0.9996
#
# [TabSyn] Phase 2: Training Diffusion Model...
# Epoch 10/100 | Loss: 0.4806
# Epoch 20/100 | Loss: 0.2955
# Epoch 30/100 | Loss: 0.2275
# Epoch 40/100 | Loss: 0.1977
# Epoch 50/100 | Loss: 0.1801
# Epoch 60/100 | Loss: 0.1756
# Epoch 70/100 | Loss: 0.1682
# Epoch 80/100 | Loss: 0.1585
# Epoch 90/100 | Loss: 0.1614
# Epoch 100/100 | Loss: 0.1494
# [TabSyn] Diffusion training completed!
# [TabSyn] Auto-generating 1382 synthetic samples in /mnt/c/Users/User/Documents/CapStoneA/Katabatic/synthetic/car/tabsyn ...
# [TabSyn] Sampling 1382 rows...
#
# [TabSyn] Target column '6' distribution:
#   Synthetic: {0: 510, 1: 220, 2: 554, 3: 98}
#   Original:  {0: 307, 1: 55, 2: 968, 3: 52}
#
# [TabSyn] Synthetic data saved:
#   X -> /mnt/c/Users/User/Documents/CapStoneA/Katabatic/synthetic/car/tabsyn/x_synth.csv
#   y -> /mnt/c/Users/User/Documents/CapStoneA/Katabatic/synthetic/car/tabsyn/y_synth.csv
# /home/baoduy/.cache/pypoetry/virtualenvs/katabatic-kYbufOe8-py3.11/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/baoduy/.cache/pypoetry/virtualenvs/katabatic-kYbufOe8-py3.11/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [07:18:33] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Results saved to: Results/car/tabsyn_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.6156
# F1 Score: 0.6273
#
# MLP:
# Accuracy: 0.7023
# F1 Score: 0.7264
#
# RF:
# Accuracy: 0.6272
# F1 Score: 0.6648
#
# XGBoost:
# Accuracy: 0.6214
# F1 Score: 0.6667
# Train test split pipeline executed successfully.

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "adult.csv"
output_path = ROOT / "discretized_data" / "adult.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "adult")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "adult" / "tabsyn")

pipeline = TrainTestSplitPipeline(model=TabSyn)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
    batch_size=512,
    d_token = 64,               
    n_layers_vae = 4,  
    hid_dim_vae = 128,
    diffusion_lr=2e-3
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/User/Documents/CapStoneA/Katabatic/raw_data/adult.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/User/Documents/CapStoneA/Katabatic/discretized_data/adult.csv
# Loaded data with shape: (32561, 15)
# Saved train/test full data
# Train size: (26048, 15), Test size: (6513, 15)
# Train label distribution:
#  class
# 0    0.759175
# 1    0.240825
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.759251
# 1    0.240749
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (26048, 14) (26048,)
# Test shape: (6513, 14) (6513,)
# [TabSyn] Loading training data from /mnt/c/Users/User/Documents/CapStoneA/Katabatic/sample_data/adult/train_full.csv...
# [TabSyn] Found 0 numerical and 15 categorical columns (target='class')
#
# [TabSyn] Phase 1: Training VAE...
# Epoch 10/100 | Recon: 0.6927 (Num: 0.0000, Cat: 0.3463) | KL: 162.9910 | Beta: 0.001440
# Epoch 20/100 | Recon: 0.2786 (Num: 0.0000, Cat: 0.1393) | KL: 64.9903 | Beta: 0.003040
# Epoch 30/100 | Recon: 0.1959 (Num: 0.0000, Cat: 0.0980) | KL: 39.3161 | Beta: 0.004640
# Epoch 40/100 | Recon: 0.1199 (Num: 0.0000, Cat: 0.0599) | KL: 25.5106 | Beta: 0.006240
# Epoch 50/100 | Recon: 0.0579 (Num: 0.0000, Cat: 0.0289) | KL: 18.4369 | Beta: 0.007840
# Epoch 60/100 | Recon: 0.0479 (Num: 0.0000, Cat: 0.0239) | KL: 15.6243 | Beta: 0.008000
# Epoch 70/100 | Recon: 0.0443 (Num: 0.0000, Cat: 0.0221) | KL: 13.8935 | Beta: 0.008000
# Epoch 80/100 | Recon: 0.0409 (Num: 0.0000, Cat: 0.0204) | KL: 12.7948 | Beta: 0.008000
# Epoch 90/100 | Recon: 0.0345 (Num: 0.0000, Cat: 0.0172) | KL: 12.2094 | Beta: 0.008000
# Epoch 100/100 | Recon: 0.0343 (Num: 0.0000, Cat: 0.0171) | KL: 11.8988 | Beta: 0.008000
# [TabSyn] VAE training completed!
#
# [TabSyn] Extracting latent embeddings...
# [TabSyn] Latent embeddings shape: torch.Size([26048, 1920])
# [TabSyn] Latent stats - mean: -0.0000, std: 1.0000
#
# [TabSyn] Phase 2: Training Diffusion Model...
# Epoch 10/100 | Loss: 0.7920
# Epoch 20/100 | Loss: 0.7888
# Epoch 30/100 | Loss: 0.7843
# Epoch 40/100 | Loss: 0.7788
# Epoch 50/100 | Loss: 0.7732
# Epoch 60/100 | Loss: 0.7674
# Epoch 70/100 | Loss: 0.7620
# Epoch 80/100 | Loss: 0.7574
# Epoch 90/100 | Loss: 0.7537
# Epoch 100/100 | Loss: 0.7514
# [TabSyn] Diffusion training completed!
# [TabSyn] Auto-generating 26048 synthetic samples in /mnt/c/Users/User/Documents/CapStoneA/Katabatic/synthetic/adult/tabsyn ...
# [TabSyn] Sampling 26048 rows...
#
# [TabSyn] Target column 'class' distribution:
#   Synthetic: {0: 13321, 1: 12727}
#   Original:  {0: 19775, 1: 6273}
#
# [TabSyn] Synthetic data saved:
#   X -> /mnt/c/Users/User/Documents/CapStoneA/Katabatic/synthetic/adult/tabsyn/x_synth.csv
#   y -> /mnt/c/Users/User/Documents/CapStoneA/Katabatic/synthetic/adult/tabsyn/y_synth.csv
# /home/baoduy/.cache/pypoetry/virtualenvs/katabatic-kYbufOe8-py3.11/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Results saved to: Results/adult/tabsyn_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.7176
# F1 Score: 0.6414
# AUC: 0.3948
#
# MLP:
# Accuracy: 0.5222
# F1 Score: 0.5555
# AUC: 0.5907
#
# RF:
# Accuracy: 0.5927
# F1 Score: 0.6171
# AUC: 0.5452
#
# XGBoost:
# Accuracy: 0.6522
# F1 Score: 0.6602
# AUC: 0.5891
# Train test split pipeline executed successfully.

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "magic.csv"
output_path = ROOT / "discretized_data" / "magic.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "magic")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "magic" / "tabsyn")

pipeline = TrainTestSplitPipeline(model=TabSyn)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
    batch_size=512,
    d_token = 32,               
    n_layers_vae = 4,  
    hid_dim_vae = 64,
    diffusion_lr=2e-3
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/User/Documents/CapStoneA/Katabatic/raw_data/magic.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/User/Documents/CapStoneA/Katabatic/discretized_data/magic.csv
# Loaded data with shape: (19020, 11)
# Saved train/test full data
# Train size: (15216, 11), Test size: (3804, 11)
# Train label distribution:
#  class
# 0    0.648396
# 1    0.351604
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.648265
# 1    0.351735
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (15216, 10) (15216,)
# Test shape: (3804, 10) (3804,)
# [TabSyn] Loading training data from /mnt/c/Users/User/Documents/CapStoneA/Katabatic/sample_data/magic/train_full.csv...
# [TabSyn] Found 0 numerical and 11 categorical columns (target='class')
#
# [TabSyn] Phase 1: Training VAE...
# Epoch 10/100 | Recon: 2.1875 (Num: 0.0000, Cat: 1.0938) | KL: 155.6227 | Beta: 0.001440
# Epoch 20/100 | Recon: 0.4861 (Num: 0.0000, Cat: 0.2430) | KL: 77.5312 | Beta: 0.003040
# Epoch 30/100 | Recon: 0.2362 (Num: 0.0000, Cat: 0.1181) | KL: 42.5270 | Beta: 0.004640
# Epoch 40/100 | Recon: 0.1404 (Num: 0.0000, Cat: 0.0702) | KL: 29.7376 | Beta: 0.006240
# Epoch 50/100 | Recon: 0.1149 (Num: 0.0000, Cat: 0.0574) | KL: 22.6765 | Beta: 0.007840
# Epoch 60/100 | Recon: 0.0544 (Num: 0.0000, Cat: 0.0272) | KL: 18.2439 | Beta: 0.008000
# Epoch 70/100 | Recon: 0.0706 (Num: 0.0000, Cat: 0.0353) | KL: 16.5175 | Beta: 0.008000
# Epoch 80/100 | Recon: 0.0461 (Num: 0.0000, Cat: 0.0231) | KL: 14.6691 | Beta: 0.008000
# Epoch 90/100 | Recon: 0.0530 (Num: 0.0000, Cat: 0.0265) | KL: 14.2172 | Beta: 0.008000
# Epoch 100/100 | Recon: 0.0333 (Num: 0.0000, Cat: 0.0166) | KL: 13.7151 | Beta: 0.008000
# [TabSyn] VAE training completed!
#
# [TabSyn] Extracting latent embeddings...
# [TabSyn] Latent embeddings shape: torch.Size([15216, 704])
# [TabSyn] Latent stats - mean: -0.0000, std: 1.0000
#
# [TabSyn] Phase 2: Training Diffusion Model...
# Epoch 10/100 | Loss: 0.3776
# Epoch 20/100 | Loss: 0.3570
# Epoch 30/100 | Loss: 0.3482
# Epoch 40/100 | Loss: 0.3414
# Epoch 50/100 | Loss: 0.3333
# Epoch 60/100 | Loss: 0.3273
# Epoch 70/100 | Loss: 0.3190
# Epoch 80/100 | Loss: 0.3149
# Epoch 90/100 | Loss: 0.3114
# Epoch 100/100 | Loss: 0.3086
# [TabSyn] Diffusion training completed!
# [TabSyn] Auto-generating 15216 synthetic samples in /mnt/c/Users/User/Documents/CapStoneA/Katabatic/synthetic/magic/tabsyn ...
# [TabSyn] Sampling 15216 rows...
#
# [TabSyn] Target column 'class' distribution:
#   Synthetic: {0: 6393, 1: 8823}
#   Original:  {0: 9866, 1: 5350}
#
# [TabSyn] Synthetic data saved:
#   X -> /mnt/c/Users/User/Documents/CapStoneA/Katabatic/synthetic/magic/tabsyn/x_synth.csv
#   y -> /mnt/c/Users/User/Documents/CapStoneA/Katabatic/synthetic/magic/tabsyn/y_synth.csv
# /home/baoduy/.cache/pypoetry/virtualenvs/katabatic-kYbufOe8-py3.11/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Results saved to: Results/magic/tabsyn_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.3517
# F1 Score: 0.1830
# AUC: 0.8150
#
# MLP:
# Accuracy: 0.4934
# F1 Score: 0.4955
# AUC: 0.5858
#
# RF:
# Accuracy: 0.4490
# F1 Score: 0.4250
# AUC: 0.5898
#
# XGBoost:
# Accuracy: 0.6057
# F1 Score: 0.6114
# AUC: 0.5898
# Train test split pipeline executed successfully.

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "nursery.csv"
output_path = ROOT / "discretized_data" / "nursery.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "nursery")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "nursery" / "tabsyn")

pipeline = TrainTestSplitPipeline(model=TabSyn)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
    batch_size=256,
    d_token =32,               
    n_layers_vae = 4,  
    hid_dim_vae = 64,
    diffusion_lr=2e-3
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/User/Documents/CapStoneA/Katabatic/raw_data/nursery.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/User/Documents/CapStoneA/Katabatic/discretized_data/nursery.csv
# Loaded data with shape: (12960, 9)
# Saved train/test full data
# Train size: (10368, 9), Test size: (2592, 9)
# Train label distribution:
#  8
# 0    0.333333
# 1    0.329186
# 3    0.312018
# 4    0.025270
# 2    0.000193
# Name: proportion, dtype: float64
# Test label distribution:
#  8
# 0    0.333333
# 1    0.329090
# 3    0.312114
# 4    0.025463
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (10368, 8) (10368,)
# Test shape: (2592, 8) (2592,)
# [TabSyn] Loading training data from /mnt/c/Users/User/Documents/CapStoneA/Katabatic/sample_data/nursery/train_full.csv...
# [TabSyn] Found 0 numerical and 9 categorical columns (target='8')
#
# [TabSyn] Phase 1: Training VAE...
# Epoch 10/100 | Recon: 0.1161 (Num: 0.0000, Cat: 0.0580) | KL: 77.5642 | Beta: 0.001440
# Epoch 20/100 | Recon: 0.0416 (Num: 0.0000, Cat: 0.0208) | KL: 28.9496 | Beta: 0.003040
# Epoch 30/100 | Recon: 0.1123 (Num: 0.0000, Cat: 0.0561) | KL: 17.8158 | Beta: 0.004640
# Epoch 40/100 | Recon: 0.0308 (Num: 0.0000, Cat: 0.0154) | KL: 14.2336 | Beta: 0.006240
# Epoch 50/100 | Recon: 0.0325 (Num: 0.0000, Cat: 0.0163) | KL: 10.5049 | Beta: 0.007840
# Epoch 60/100 | Recon: 0.0211 (Num: 0.0000, Cat: 0.0105) | KL: 9.2433 | Beta: 0.008000
# Epoch 70/100 | Recon: 0.0246 (Num: 0.0000, Cat: 0.0123) | KL: 8.7809 | Beta: 0.008000
# Epoch 80/100 | Recon: 0.0181 (Num: 0.0000, Cat: 0.0090) | KL: 8.0309 | Beta: 0.008000
# Epoch 90/100 | Recon: 0.0144 (Num: 0.0000, Cat: 0.0072) | KL: 7.6588 | Beta: 0.008000
# Epoch 100/100 | Recon: 0.0109 (Num: 0.0000, Cat: 0.0055) | KL: 7.4694 | Beta: 0.008000
# [TabSyn] VAE training completed!
#
# [TabSyn] Extracting latent embeddings...
# [TabSyn] Latent embeddings shape: torch.Size([10368, 576])
# [TabSyn] Latent stats - mean: -0.0000, std: 0.9999
#
# [TabSyn] Phase 2: Training Diffusion Model...
# Epoch 10/100 | Loss: 0.2667
# Epoch 20/100 | Loss: 0.2478
# Epoch 30/100 | Loss: 0.2388
# Epoch 40/100 | Loss: 0.2292
# Epoch 50/100 | Loss: 0.2216
# Epoch 60/100 | Loss: 0.2173
# Epoch 70/100 | Loss: 0.2033
# Epoch 80/100 | Loss: 0.2012
# Epoch 90/100 | Loss: 0.1946
# Epoch 100/100 | Loss: 0.1920
# [TabSyn] Diffusion training completed!
# [TabSyn] Auto-generating 10368 synthetic samples in /mnt/c/Users/User/Documents/CapStoneA/Katabatic/synthetic/nursery/tabsyn ...
# [TabSyn] Sampling 10368 rows...
#
# [TabSyn] Target column '8' distribution:
#   Synthetic: {0: 3061, 1: 3054, 2: 111, 3: 2344, 4: 1798}
#   Original:  {0: 3456, 1: 3413, 2: 2, 3: 3235, 4: 262}
#
# [TabSyn] Synthetic data saved:
#   X -> /mnt/c/Users/User/Documents/CapStoneA/Katabatic/synthetic/nursery/tabsyn/x_synth.csv
#   y -> /mnt/c/Users/User/Documents/CapStoneA/Katabatic/synthetic/nursery/tabsyn/y_synth.csv
# /home/baoduy/.cache/pypoetry/virtualenvs/katabatic-kYbufOe8-py3.11/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/baoduy/.cache/pypoetry/virtualenvs/katabatic-kYbufOe8-py3.11/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [07:48:32] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Results saved to: Results/nursery/tabsyn_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.6435
# F1 Score: 0.6164
#
# MLP:
# Accuracy: 0.6609
# F1 Score: 0.6663
#
# RF:
# Accuracy: 0.5108
# F1 Score: 0.5313
#
# XGBoost:
# Accuracy: 0.5725
# F1 Score: 0.5860
# Train test split pipeline executed successfully.

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "shuttle.csv"
output_path = ROOT / "discretized_data" / "shuttle.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "shuttle")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "shuttle" / "tabsyn")

pipeline = TrainTestSplitPipeline(model=TabSyn)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
    batch_size=512,
    d_token = 32,               
    n_layers_vae = 4,  
    hid_dim_vae = 64,
    diffusion_lr=2e-3
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/User/Documents/CapStoneA/Katabatic/raw_data/shuttle.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/User/Documents/CapStoneA/Katabatic/discretized_data/shuttle.csv
# Loaded data with shape: (58000, 10)
# Saved train/test full data
# Train size: (46400, 10), Test size: (11600, 10)
# Train label distribution:
#  class
# 0    0.785970
# 3    0.153491
# 4    0.056336
# 2    0.002953
# 1    0.000862
# 6    0.000216
# 5    0.000172
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.785948
# 3    0.153534
# 4    0.056293
# 2    0.002931
# 1    0.000862
# 6    0.000259
# 5    0.000172
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (46400, 9) (46400,)
# Test shape: (11600, 9) (11600,)
# [TabSyn] Loading training data from /mnt/c/Users/User/Documents/CapStoneA/Katabatic/sample_data/shuttle/train_full.csv...
# [TabSyn] Found 0 numerical and 10 categorical columns (target='class')
#
# [TabSyn] Phase 1: Training VAE...
# Epoch 10/100 | Recon: 0.4053 (Num: 0.0000, Cat: 0.2026) | KL: 103.2369 | Beta: 0.001440
# Epoch 20/100 | Recon: 0.1250 (Num: 0.0000, Cat: 0.0625) | KL: 36.3986 | Beta: 0.003040
# Epoch 30/100 | Recon: 0.0469 (Num: 0.0000, Cat: 0.0234) | KL: 21.2643 | Beta: 0.004640
# Epoch 40/100 | Recon: 0.1177 (Num: 0.0000, Cat: 0.0588) | KL: 15.2543 | Beta: 0.006240
# Epoch 50/100 | Recon: 0.0287 (Num: 0.0000, Cat: 0.0144) | KL: 11.9150 | Beta: 0.007840
# Epoch 60/100 | Recon: 0.0484 (Num: 0.0000, Cat: 0.0242) | KL: 10.3461 | Beta: 0.008000
# Epoch 70/100 | Recon: 0.0268 (Num: 0.0000, Cat: 0.0134) | KL: 9.3896 | Beta: 0.008000
# Epoch 80/100 | Recon: 0.0320 (Num: 0.0000, Cat: 0.0160) | KL: 8.6678 | Beta: 0.008000
# Epoch 90/100 | Recon: 0.0198 (Num: 0.0000, Cat: 0.0099) | KL: 8.5392 | Beta: 0.008000
# Epoch 100/100 | Recon: 0.0173 (Num: 0.0000, Cat: 0.0086) | KL: 8.2316 | Beta: 0.008000
# [TabSyn] VAE training completed!
#
# [TabSyn] Extracting latent embeddings...
# [TabSyn] Latent embeddings shape: torch.Size([46400, 640])
# [TabSyn] Latent stats - mean: 0.0000, std: 1.0000
#
# [TabSyn] Phase 2: Training Diffusion Model...
# Epoch 10/100 | Loss: 0.2996
# Epoch 20/100 | Loss: 0.2913
# Epoch 30/100 | Loss: 0.2864
# Epoch 40/100 | Loss: 0.2801
# Epoch 50/100 | Loss: 0.2721
# Epoch 60/100 | Loss: 0.2685
# Epoch 70/100 | Loss: 0.2609
# Epoch 80/100 | Loss: 0.2557
# Epoch 90/100 | Loss: 0.2529
# Epoch 100/100 | Loss: 0.2505
# [TabSyn] Diffusion training completed!
# [TabSyn] Auto-generating 46400 synthetic samples in /mnt/c/Users/User/Documents/CapStoneA/Katabatic/synthetic/shuttle/tabsyn ...
# [TabSyn] Sampling 46400 rows...
#
# [TabSyn] Target column 'class' distribution:
#   Synthetic: {0: 13679, 1: 2874, 2: 2676, 3: 15488, 4: 8418, 5: 823, 6: 2442}
#   Original:  {0: 36469, 1: 40, 2: 137, 3: 7122, 4: 2614, 5: 8, 6: 10}
#
# [TabSyn] Synthetic data saved:
#   X -> /mnt/c/Users/User/Documents/CapStoneA/Katabatic/synthetic/shuttle/tabsyn/x_synth.csv
#   y -> /mnt/c/Users/User/Documents/CapStoneA/Katabatic/synthetic/shuttle/tabsyn/y_synth.csv
# /home/baoduy/.cache/pypoetry/virtualenvs/katabatic-kYbufOe8-py3.11/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [08:06:36] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Results saved to: Results/shuttle/tabsyn_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.8774
# F1 Score: 0.8712
#
# MLP:
# Accuracy: 0.8199
# F1 Score: 0.8298
#
# RF:
# Accuracy: 0.7822
# F1 Score: 0.7992
#
# XGBoost:
# Accuracy: 0.8614
# F1 Score: 0.8670
# Train test split pipeline executed successfully.
