# %%
# Imports
import sys
from pathlib import Path


# Resolve project root and ensure it's on sys.path
ROOT = Path.cwd().resolve()
for _ in range(5):
    if (ROOT / "pyproject.toml").exists() or (ROOT / "raw_data").exists():
        break
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
from katabatic.pipeline.train_test_split.pipeline import TrainTestSplitPipeline
from src.pategan import PateGan
from utils import discretize_preprocess

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "car.csv"
output_path = ROOT / "discretized_data" / "car.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "car")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "car" / "pategan")

pipeline = TrainTestSplitPipeline(model=PateGan)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/raw_data/car.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/discretized_data/car.csv
# Loaded data with shape: (1728, 7)
# Saved train/test full data
# Train size: (1382, 7), Test size: (346, 7)
# Train label distribution:
#  6
# 2    0.700434
# 0    0.222142
# 1    0.039797
# 3    0.037627
# Name: proportion, dtype: float64
# Test label distribution:
#  6
# 2    0.699422
# 0    0.222543
# 1    0.040462
# 3    0.037572
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (1382, 6) (1382,)
# Test shape: (346, 6) (346,)
# Class distribution: {0: 307, 1: 55, 2: 968, 3: 52}
# Class weights: [1.1254072 6.2818184 0.3569215 6.644231 ]
# [PATE-GAN] Training | ε_target=1.0 | λ=12.0 | Teachers=7 | Weighted=True
# Iter     0 | ε ≈ 0.0523
# Iter    10 | ε ≈ 0.5754
# [PATE-GAN] Target ε=1.0 reached at ε=1.0461
# Generating with minority oversampling (min 69 per class)...
# Class 0: Generated 105, Using 307 (target: 22.21%)
# Class 1: Generated 104, Using 69 (target: 3.98%)
# Class 2: Generated 160, Using 968 (target: 70.04%)
# Class 3: Generated 143, Using 69 (target: 3.76%)
#
# Synthetic vs Original Distribution:
# Class 0: Synth= 301 ( 21.8%)  |  Orig= 307 ( 22.2%)
# Class 1: Synth=  67 (  4.8%)  |  Orig=  55 (  4.0%)
# Class 2: Synth= 947 ( 68.5%)  |  Orig= 968 ( 70.0%)
# Class 3: Synth=  67 (  4.8%)  |  Orig=  52 (  3.8%)
# /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:780: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [12:50:39] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Results saved to: Results/car/pategan_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.6994
# F1 Score: 0.5757
#
# MLP:
# Accuracy: 0.6012
# F1 Score: 0.5335
#
# RF:
# Accuracy: 0.4624
# F1 Score: 0.4871
#
# XGBoost:
# Accuracy: 0.3988
# F1 Score: 0.4463
# Train test split pipeline executed successfully.

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "adult.csv"
output_path = ROOT / "discretized_data" / "adult.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "adult")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "adult" / "pategan")

pipeline = TrainTestSplitPipeline(model=PateGan)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/raw_data/adult.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/discretized_data/adult.csv
# Loaded data with shape: (32561, 15)
# Saved train/test full data
# Train size: (26048, 15), Test size: (6513, 15)
# Train label distribution:
#  class
# 0    0.759175
# 1    0.240825
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.759251
# 1    0.240749
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (26048, 14) (26048,)
# Test shape: (6513, 14) (6513,)
# Class distribution: {0: 19775, 1: 6273}
# Class weights: [0.65860933 2.0761995 ]
# [PATE-GAN] Training | ε_target=1.0 | λ=12.0 | Teachers=7 | Weighted=True
# Iter     0 | ε ≈ 0.0523
# Iter    10 | ε ≈ 0.5754
# [PATE-GAN] Target ε=1.0 reached at ε=1.0461
# Generating with minority oversampling (min 2604 per class)...
# Class 0: Generated 2927, Using 19775 (target: 75.92%)
# Class 1: Generated 2705, Using 6273 (target: 24.08%)
#
# Synthetic vs Original Distribution:
# Class 0: Synth=19775 ( 75.9%)  |  Orig=19775 ( 75.9%)
# Class 1: Synth=6273 ( 24.1%)  |  Orig=6273 ( 24.1%)
# /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:780: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Results saved to: Results/adult/pategan_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.7593
# F1 Score: 0.6553
# AUC: 0.3205
#
# MLP:
# Accuracy: 0.6504
# F1 Score: 0.6250
# AUC: 0.5178
#
# RF:
# Accuracy: 0.4574
# F1 Score: 0.4948
# AUC: 0.4560
#
# XGBoost:
# Accuracy: 0.3435
# F1 Score: 0.3597
# AUC: 0.3887
# Train test split pipeline executed successfully.

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "magic.csv"
output_path = ROOT / "discretized_data" / "magic.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "magic")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "magic" / "pategan")

pipeline = TrainTestSplitPipeline(model=PateGan)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/raw_data/magic.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/discretized_data/magic.csv
# Loaded data with shape: (19020, 11)
# Saved train/test full data
# Train size: (15216, 11), Test size: (3804, 11)
# Train label distribution:
#  class
# 0    0.648396
# 1    0.351604
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.648265
# 1    0.351735
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (15216, 10) (15216,)
# Test shape: (3804, 10) (3804,)
# Class distribution: {0: 9866, 1: 5350}
# Class weights: [0.7711332 1.4220561]
# [PATE-GAN] Training | ε_target=1.0 | λ=12.0 | Teachers=7 | Weighted=True
# Iter     0 | ε ≈ 0.0523
# Iter    10 | ε ≈ 0.5754
# [PATE-GAN] Target ε=1.0 reached at ε=1.0461
# Generating with minority oversampling (min 1521 per class)...
# Class 0: Generated 2008, Using 9866 (target: 64.84%)
# Class 1: Generated 1576, Using 5350 (target: 35.16%)
#
# Synthetic vs Original Distribution:
# Class 0: Synth=9866 ( 64.8%)  |  Orig=9866 ( 64.8%)
# Class 1: Synth=5350 ( 35.2%)  |  Orig=5350 ( 35.2%)
# /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:780: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Results saved to: Results/magic/pategan_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.6483
# F1 Score: 0.5099
# AUC: 0.3868
#
# MLP:
# Accuracy: 0.5828
# F1 Score: 0.5707
# AUC: 0.5373
#
# RF:
# Accuracy: 0.4779
# F1 Score: 0.4890
# AUC: 0.4394
#
# XGBoost:
# Accuracy: 0.3764
# F1 Score: 0.3669
# AUC: 0.4003
# Train test split pipeline executed successfully.

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "shuttle.csv"
output_path = ROOT / "discretized_data" / "shuttle.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "shuttle")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "shuttle" / "PateGan")

pipeline = TrainTestSplitPipeline(model=PateGan)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/raw_data/shuttle.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/discretized_data/shuttle.csv
# Loaded data with shape: (58000, 10)
# Saved train/test full data
# Train size: (46400, 10), Test size: (11600, 10)
# Train label distribution:
#  class
# 0    0.785970
# 3    0.153491
# 4    0.056336
# 2    0.002953
# 1    0.000862
# 6    0.000216
# 5    0.000172
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.785948
# 3    0.153534
# 4    0.056293
# 2    0.002931
# 1    0.000862
# 6    0.000259
# 5    0.000172
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (46400, 9) (46400,)
# Test shape: (11600, 9) (11600,)
# Class distribution: {0: 36469, 1: 40, 2: 137, 3: 7122, 4: 2614, 5: 8, 6: 10}
# Class weights: [1.8175907e-01 1.6571428e+02 4.8383732e+01 9.3071771e-01 2.5357962e+00
#  8.2857141e+02 6.6285712e+02]
# [PATE-GAN] Training | ε_target=1.0 | λ=12.0 | Teachers=7 | Weighted=True
# Iter     0 | ε ≈ 0.0523
# Iter    10 | ε ≈ 0.5754
# [PATE-GAN] Target ε=1.0 reached at ε=1.0461
# Generating with minority oversampling (min 1325 per class)...
# Class 0: Generated 1405, Using 36469 (target: 78.60%)
# Class 1: Generated 2059, Using 1325 (target: 0.09%)
# Class 2: Generated 1891, Using 1325 (target: 0.30%)
# Class 3: Generated 1652, Using 7121 (target: 15.35%)
# Class 4: Generated 2292, Using 2614 (target: 5.63%)
# Class 5: Generated 1635, Using 1325 (target: 0.02%)
# Class 6: Generated 1354, Using 1325 (target: 0.02%)
#
# Synthetic vs Original Distribution:
# Class 0: Synth=32802 ( 70.7%)  |  Orig=36469 ( 78.6%)
# Class 1: Synth=1203 (  2.6%)  |  Orig=  40 (  0.1%)
# Class 2: Synth=1220 (  2.6%)  |  Orig= 137 (  0.3%)
# Class 3: Synth=6408 ( 13.8%)  |  Orig=7122 ( 15.3%)
# Class 4: Synth=2389 (  5.1%)  |  Orig=2614 (  5.6%)
# Class 5: Synth=1185 (  2.6%)  |  Orig=   8 (  0.0%)
# Class 6: Synth=1193 (  2.6%)  |  Orig=  10 (  0.0%)
# /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:780: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [12:53:46] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Results saved to: Results/shuttle/PateGan_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.7859
# F1 Score: 0.6917
#
# MLP:
# Accuracy: 0.5328
# F1 Score: 0.5555
#
# RF:
# Accuracy: 0.2153
# F1 Score: 0.2641
#
# XGBoost:
# Accuracy: 0.5031
# F1 Score: 0.5368
# Train test split pipeline executed successfully.

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "nursery.csv"
output_path = ROOT / "discretized_data" / "nursery.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "nursery")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "nursery" / "pategan")

pipeline = TrainTestSplitPipeline(model=PateGan)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
    batch_size=256,
    d_token =32,               
    n_layers_vae = 4,  
    hid_dim_vae = 64,
    diffusion_lr=2e-3
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/raw_data/nursery.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/discretized_data/nursery.csv
# Loaded data with shape: (12960, 9)
# Saved train/test full data
# Train size: (10368, 9), Test size: (2592, 9)
# Train label distribution:
#  8
# 0    0.333333
# 1    0.329186
# 3    0.312018
# 4    0.025270
# 2    0.000193
# Name: proportion, dtype: float64
# Test label distribution:
#  8
# 0    0.333333
# 1    0.329090
# 3    0.312114
# 4    0.025463
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (10368, 8) (10368,)
# Test shape: (2592, 8) (2592,)
# Class distribution: {0: 3456, 1: 3413, 2: 2, 3: 3235, 4: 262}
# Class weights: [6.000000e-01 6.075593e-01 1.036800e+03 6.409892e-01 7.914504e+00]
# [PATE-GAN] Training | ε_target=1.0 | λ=12.0 | Teachers=7 | Weighted=True
# Iter     0 | ε ≈ 0.0523
# Iter    10 | ε ≈ 0.5754
# [PATE-GAN] Target ε=1.0 reached at ε=1.0461
# Generating with minority oversampling (min 414 per class)...
# Class 0: Generated 437, Using 3456 (target: 33.33%)
# Class 1: Generated 446, Using 3413 (target: 32.92%)
# Class 2: Generated 507, Using 414 (target: 0.02%)
# Class 3: Generated 442, Using 3235 (target: 31.20%)
# Class 4: Generated 472, Using 414 (target: 2.53%)
#
# Synthetic vs Original Distribution:
# Class 0: Synth=3277 ( 31.6%)  |  Orig=3456 ( 33.3%)
# Class 1: Synth=3223 ( 31.1%)  |  Orig=3413 ( 32.9%)
# Class 2: Synth= 396 (  3.8%)  |  Orig=   2 (  0.0%)
# Class 3: Synth=3078 ( 29.7%)  |  Orig=3235 ( 31.2%)
# Class 4: Synth= 394 (  3.8%)  |  Orig= 262 (  2.5%)
# /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:780: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Results saved to: Results/nursery/pategan_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.3237
# F1 Score: 0.3144
#
# MLP:
# Accuracy: 0.3237
# F1 Score: 0.3190
#
# RF:
# Accuracy: 0.2921
# F1 Score: 0.3142
#
# XGBoost:
# Accuracy: 0.2809
# F1 Score: 0.3018
# Train test split pipeline executed successfully.
# /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [12:54:34] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
