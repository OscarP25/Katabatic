# %%
# Imports
import sys
from pathlib import Path

# Resolve project root and ensure it's on sys.path
ROOT = Path.cwd().resolve()
for _ in range(5):
    if (ROOT / "pyproject.toml").exists() or (ROOT / "raw_data").exists():
        break
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from katabatic.pipeline.train_test_split.pipeline import TrainTestSplitPipeline
from utils import discretize_preprocess
from katabatic.models.pategan.models import PATEGAN
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 14
#      11 if str(ROOT) not in sys.path:
#      12     sys.path.insert(0, str(ROOT))
# ---> 14 from katabatic.pipeline.train_test_split.pipeline import TrainTestSplitPipeline
#      15 from utils import discretize_preprocess
#      16 from katabatic.models.pategan.models import PATEGAN
#
# File ~\Downloads\capstone project\Intelligent-IoT-Data-Management-main\IOT data science\Katabatic\katabatic\pipeline\train_test_split\pipeline.py:3
#       1 from katabatic.pipeline.base_pipeline import Pipeline
#       2 from katabatic.models.base_model import Model
# ----> 3 from katabatic.evaluate.tstr.evaluation import TSTREvaluation
#       4 from katabatic.utils.split_dataset import split_dataset
#       7 class TrainTestSplitPipeline(Pipeline):
#
# File ~\Downloads\capstone project\Intelligent-IoT-Data-Management-main\IOT data science\Katabatic\katabatic\evaluate\tstr\evaluation.py:11
#       9 from sklearn.ensemble import RandomForestClassifier
#      10 from sklearn.preprocessing import StandardScaler
# ---> 11 from xgboost import XGBClassifier
#      12 from sklearn.metrics import accuracy_score, f1_score, roc_auc_score
#      14 from katabatic.evaluate.base_evaluation import Evaluation
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "car.csv"
output_path = ROOT / "discretized_data" / "car.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))
# Out:
# Preprocessing: /Users/vikumdabare/Documents/Work/Katabatic/katabatic/raw_data/car.csv
# Saved preprocessed discrete dataset to: /Users/vikumdabare/Documents/Work/Katabatic/katabatic/discretized_data/car.csv

# %%
# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "car")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "car" / "pategan")

pipeline = TrainTestSplitPipeline(model=PATEGAN)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
)
print(result)
# Out:
# Loaded data with shape: (1728, 7)
# Saved train/test full data
# Train size: (1382, 7), Test size: (346, 7)
# Train label distribution:
#  6
# 2    0.700434
# 0    0.222142
# 1    0.039797
# 3    0.037627
# Name: proportion, dtype: float64
# Test label distribution:
#  6
# 2    0.699422
# 0    0.222543
# 1    0.040462
# 3    0.037572
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (1382, 6) (1382,)
# Test shape: (346, 6) (346,)
# Remapped y classes: [0, 1, 2, 3] -> [0, 1, 2, 3]
# Loaded training data: X shape=(1382, 6), y shape=(1382,)
# WARNING:tensorflow:From /Users/vikumdabare/Documents/Work/Katabatic/katabatic/.venv/lib/python3.11/site-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1762106597.866865  805399 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# Training PATE-GAN with ε=1.0, δ=1e-05
# Teachers: 10, Iterations: 10000
# Training: 100%|██████████| 10000/10000 [00:40<00:00, 247.88it/s]
# Training completed!
#
# Generating 1382 synthetic samples...
# [PATEGAN] Adding 3 dummy samples to cover classes: [0, 1, 2]
# Remapped y_test.csv to match synthetic data encoding
# Saved x_synth.csv to /Users/vikumdabare/Documents/Work/Katabatic/katabatic/synthetic/car/pategan/x_synth.csv
# Saved y_synth.csv to /Users/vikumdabare/Documents/Work/Katabatic/katabatic/synthetic/car/pategan/y_synth.csv
# Saved metadata.json to /Users/vikumdabare/Documents/Work/Katabatic/katabatic/synthetic/car/pategan/metadata.json
#
# Results saved to: Results/car/pategan_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.1850
# F1 Score: 0.2064
#
# MLP:
# Accuracy: 0.1387
# F1 Score: 0.1167
#
# RF:
# Accuracy: 0.1821
# F1 Score: 0.2559
#
# XGBoost:
# Accuracy: 0.1821
# F1 Score: 0.0806
# Train test split pipeline executed successfully.
# /Users/vikumdabare/Documents/Work/Katabatic/katabatic/.venv/lib/python3.11/site-packages/xgboost/training.py:183: UserWarning: [23:33:58] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
