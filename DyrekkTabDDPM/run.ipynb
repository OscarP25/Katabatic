# %%
# Imports
import sys
from pathlib import Path


# Resolve project root and ensure it's on sys.path
ROOT = Path.cwd().resolve()
for _ in range(5):
    if (ROOT / "pyproject.toml").exists() or (ROOT / "raw_data").exists():
        break
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
from katabatic.pipeline.train_test_split.pipeline import TrainTestSplitPipeline
from src.tabddpm import TabDDPM
from utils import discretize_preprocess

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "car.csv"
output_path = ROOT / "discretized_data" / "car.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "car")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "car" / "tabddpm")

pipeline = TrainTestSplitPipeline(model=TabDDPM)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/raw_data/car.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/discretized_data/car.csv
# Loaded data with shape: (1728, 7)
# Saved train/test full data
# Train size: (1382, 7), Test size: (346, 7)
# Train label distribution:
#  6
# 2    0.700434
# 0    0.222142
# 1    0.039797
# 3    0.037627
# Name: proportion, dtype: float64
# Test label distribution:
#  6
# 2    0.699422
# 0    0.222543
# 1    0.040462
# 3    0.037572
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (1382, 6) (1382,)
# Test shape: (346, 6) (346,)
# Moving entire dataset to cuda...
# Training TabDDPM: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [04:28<00:00, 37.30it/s, loss=6.03e-8]
# Generating samples: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:10<00:00,  5.08s/it]
# /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:780: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [13:47:42] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Results saved to: Results/car/tabddpm_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.6994
# F1 Score: 0.5757
#
# MLP:
# Accuracy: 0.6994
# F1 Score: 0.5757
#
# RF:
# Accuracy: 0.6214
# F1 Score: 0.5956
#
# XGBoost:
# Accuracy: 0.6098
# F1 Score: 0.5953
# Train test split pipeline executed successfully.

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "adult.csv"
output_path = ROOT / "discretized_data" / "adult.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "adult")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "adult" / "tabddpm")

pipeline = TrainTestSplitPipeline(model=TabDDPM)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/raw_data/adult.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/discretized_data/adult.csv
# Loaded data with shape: (32561, 15)
# Saved train/test full data
# Train size: (26048, 15), Test size: (6513, 15)
# Train label distribution:
#  class
# 0    0.759175
# 1    0.240825
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.759251
# 1    0.240749
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (26048, 14) (26048,)
# Test shape: (6513, 14) (6513,)
# Moving entire dataset to cuda...
# Training TabDDPM: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [05:11<00:00, 32.13it/s, loss=2.92e-7]
# Generating samples: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [04:56<00:00, 11.40s/it]
# /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:780: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Results saved to: Results/adult/tabddpm_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.7593
# F1 Score: 0.6553
# AUC: 0.5720
#
# MLP:
# Accuracy: 0.7614
# F1 Score: 0.7338
# AUC: 0.7480
#
# RF:
# Accuracy: 0.7606
# F1 Score: 0.6636
# AUC: 0.6283
#
# XGBoost:
# Accuracy: 0.5016
# F1 Score: 0.5317
# AUC: 0.5964
# Train test split pipeline executed successfully.

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "magic.csv"
output_path = ROOT / "discretized_data" / "magic.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "magic")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "magic" / "tabddpm")

pipeline = TrainTestSplitPipeline(model=TabDDPM)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/raw_data/magic.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/discretized_data/magic.csv
# Loaded data with shape: (19020, 11)
# Saved train/test full data
# Train size: (15216, 11), Test size: (3804, 11)
# Train label distribution:
#  class
# 0    0.648396
# 1    0.351604
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.648265
# 1    0.351735
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (15216, 10) (15216,)
# Test shape: (3804, 10) (3804,)
# Moving entire dataset to cuda...
# Training TabDDPM: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [04:48<00:00, 34.66it/s, loss=1.63e-7]
# Generating samples: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [02:15<00:00,  9.02s/it]
# /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:780: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Results saved to: Results/magic/tabddpm_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.6483
# F1 Score: 0.5099
# AUC: 0.5911
#
# MLP:
# Accuracy: 0.6525
# F1 Score: 0.5209
# AUC: 0.6609
#
# RF:
# Accuracy: 0.6496
# F1 Score: 0.5316
# AUC: 0.4993
#
# XGBoost:
# Accuracy: 0.5005
# F1 Score: 0.5117
# AUC: 0.4850
# Train test split pipeline executed successfully.

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "shuttle.csv"
output_path = ROOT / "discretized_data" / "shuttle.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "shuttle")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "shuttle" / "tabddpm")

pipeline = TrainTestSplitPipeline(model=TabDDPM)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/raw_data/shuttle.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/discretized_data/shuttle.csv
# Loaded data with shape: (58000, 10)
# Saved train/test full data
# Train size: (46400, 10), Test size: (11600, 10)
# Train label distribution:
#  class
# 0    0.785970
# 3    0.153491
# 4    0.056336
# 2    0.002953
# 1    0.000862
# 6    0.000216
# 5    0.000172
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.785948
# 3    0.153534
# 4    0.056293
# 2    0.002931
# 1    0.000862
# 6    0.000259
# 5    0.000172
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (46400, 9) (46400,)
# Test shape: (11600, 9) (11600,)
# Moving entire dataset to cuda...
# Training TabDDPM: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [05:02<00:00, 33.11it/s, loss=2.17e-7]
# Generating samples: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 46/46 [05:54<00:00,  7.70s/it]
# /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [14:17:41] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Results saved to: Results/shuttle/tabddpm_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.8203
# F1 Score: 0.7479
#
# MLP:
# Accuracy: 0.8413
# F1 Score: 0.7696
#
# RF:
# Accuracy: 0.8391
# F1 Score: 0.7687
#
# XGBoost:
# Accuracy: 0.8372
# F1 Score: 0.7660
# Train test split pipeline executed successfully.

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "nursery.csv"
output_path = ROOT / "discretized_data" / "nursery.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "nursery")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "nursery" / "tabddpm")

pipeline = TrainTestSplitPipeline(model=TabDDPM)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/raw_data/nursery.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/discretized_data/nursery.csv
# Loaded data with shape: (12960, 9)
# Saved train/test full data
# Train size: (10368, 9), Test size: (2592, 9)
# Train label distribution:
#  8
# 0    0.333333
# 1    0.329186
# 3    0.312018
# 4    0.025270
# 2    0.000193
# Name: proportion, dtype: float64
# Test label distribution:
#  8
# 0    0.333333
# 1    0.329090
# 3    0.312114
# 4    0.025463
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (10368, 8) (10368,)
# Test shape: (2592, 8) (2592,)
# Moving entire dataset to cuda...
# Training TabDDPM: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [04:42<00:00, 35.37it/s, loss=7.9e-8]
# Generating samples: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [01:23<00:00,  7.62s/it]
# /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:780: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [14:23:53] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Results saved to: Results/nursery/tabddpm_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.6674
# F1 Score: 0.5959
#
# MLP:
# Accuracy: 0.6609
# F1 Score: 0.6492
#
# RF:
# Accuracy: 0.6632
# F1 Score: 0.6593
#
# XGBoost:
# Accuracy: 0.6605
# F1 Score: 0.6549
# Train test split pipeline executed successfully.
