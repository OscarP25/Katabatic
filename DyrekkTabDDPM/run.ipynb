# %%
# Imports
import sys
from pathlib import Path


# Resolve project root and ensure it's on sys.path
ROOT = Path.cwd().resolve()
for _ in range(5):
    if (ROOT / "pyproject.toml").exists() or (ROOT / "raw_data").exists():
        break
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
from katabatic.pipeline.train_test_split.pipeline import TrainTestSplitPipeline
from src.tabddpm import TabDDPM
from utils import discretize_preprocess

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "car.csv"
output_path = ROOT / "discretized_data" / "car.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "car")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "car" / "tabddpm")

pipeline = TrainTestSplitPipeline(model=TabDDPM)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/raw_data/car.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/discretized_data/car.csv
# Loaded data with shape: (1728, 7)
# Saved train/test full data
# Train size: (1382, 7), Test size: (346, 7)
# Train label distribution:
#  6
# 2    0.700434
# 0    0.222142
# 1    0.039797
# 3    0.037627
# Name: proportion, dtype: float64
# Test label distribution:
#  6
# 2    0.699422
# 0    0.222543
# 1    0.040462
# 3    0.037572
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (1382, 6) (1382,)
# Test shape: (346, 6) (346,)
# Moving entire dataset to cuda...
# Training TabDDPM: 100%|███████████████████████████████████████████████████████████████████████████████████████████| 20000/20000 [05:46<00:00, 57.73it/s, loss=2.14e-10]
# Generating samples: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:12<00:00,  6.25s/it]
# /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:780: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/xgboost/training.py:199: UserWarning: [17:37:44] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Results saved to: Results/car/tabddpm_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.6994
# F1 Score: 0.5757
#
# MLP:
# Accuracy: 0.6850
# F1 Score: 0.5687
#
# RF:
# Accuracy: 0.5867
# F1 Score: 0.5430
#
# XGBoost:
# Accuracy: 0.5405
# F1 Score: 0.5240
# Train test split pipeline executed successfully.

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "adult.csv"
output_path = ROOT / "discretized_data" / "adult.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "adult")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "adult" / "tabddpm")

pipeline = TrainTestSplitPipeline(model=TabDDPM)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/raw_data/adult.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/discretized_data/adult.csv
# Loaded data with shape: (32561, 15)
# Saved train/test full data
# Train size: (26048, 15), Test size: (6513, 15)
# Train label distribution:
#  class
# 0    0.759175
# 1    0.240825
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.759251
# 1    0.240749
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (26048, 14) (26048,)
# Test shape: (6513, 14) (6513,)
# Moving entire dataset to cuda...
# Training TabDDPM: 100%|██████████████████████████████████████████████████████████████████████████████████████████| 20000/20000 [08:56<00:00, 37.29it/s, loss=-7.67e-10]
# Generating samples: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [04:40<00:00, 10.78s/it]
# /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:780: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Results saved to: Results/adult/tabddpm_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.7593
# F1 Score: 0.6553
# AUC: 0.7210
#
# MLP:
# Accuracy: 0.7528
# F1 Score: 0.6560
# AUC: 0.5012
#
# RF:
# Accuracy: 0.7588
# F1 Score: 0.6560
# AUC: 0.6110
#
# XGBoost:
# Accuracy: 0.6942
# F1 Score: 0.6695
# AUC: 0.5635
# Train test split pipeline executed successfully.

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "magic.csv"
output_path = ROOT / "discretized_data" / "magic.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "magic")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "magic" / "tabddpm")

pipeline = TrainTestSplitPipeline(model=TabDDPM)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/raw_data/magic.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/discretized_data/magic.csv
# Loaded data with shape: (19020, 11)
# Saved train/test full data
# Train size: (15216, 11), Test size: (3804, 11)
# Train label distribution:
#  class
# 0    0.648396
# 1    0.351604
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.648265
# 1    0.351735
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (15216, 10) (15216,)
# Test shape: (3804, 10) (3804,)
# Moving entire dataset to cuda...
# Training TabDDPM:  19%|█████████████████▏                                                                           | 3707/20000 [01:10<05:08, 52.84it/s, loss=3.23e-9]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 18
#      15 synthetic_dir = str(ROOT / "synthetic" / "magic" / "tabddpm")
#      17 pipeline = TrainTestSplitPipeline(model=TabDDPM)
# ---> 18 result = pipeline.run(
#      19     input_csv=input_csv,
#      20     output_dir=output_dir,
#      21     synthetic_dir=synthetic_dir,
#      22     real_test_dir=real_test_dir
#      23 )
#      24 print(result)
#
# File /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/katabatic/pipeline/train_test_split/pipeline.py:38, in TrainTestSplitPipeline.run(self, *args, **kwargs)
#      35 split_dataset(input_csv, output_dir, *args, **kwargs)
#      37 # Train the model (may consume extra kwargs like 'config')
# ---> 38 current_model.train(output_dir, *args, **kwargs)
#      40 # Filter kwargs for evaluations to avoid unexpected params (e.g., 'config')
#      41 eval_kwargs = dict(kwargs)
#
# File /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/DyrekkTabDDPM/src/tabddpm.py:188, in TabDDPM.train(self, output_dir, **kwargs)
#     185     pred_cat = F.softmax(pred_cat, dim=-1)
#     186     pred_start_idx += cat_dim
# --> 188     cat_loss = self.multinomial_diffusions[i].compute_loss(
#     189         pred_cat, X_cat_parts[i], X_cat_parts[i], t
#     190     )
#     191     multinomial_losses.append(cat_loss)
#     193 total_loss = sum(multinomial_losses) / len(multinomial_losses)
#
# File /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/DyrekkTabDDPM/src/multinomial_diffusion.py:141, in MultinomialDiffusion.compute_loss(self, x_0_pred, x_0_true, x_t, t)
#     138 true_posterior = self.q_posterior(x_t, x_0_true, t)
#     140 # Predicted posterior
# --> 141 pred_posterior = self.q_posterior(x_t, x_0_pred, t)
#     143 # KL divergence
#     144 kl = (true_posterior * (torch.log(true_posterior + 1e-10) - torch.log(pred_posterior + 1e-10))).sum(dim=-1)
#
# File /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/DyrekkTabDDPM/src/multinomial_diffusion.py:92, in MultinomialDiffusion.q_posterior(self, x_t, x_0, t)
#      89 alpha_bar_t_prev[t == 0] = 1.0
#      91 # Compute posterior: pi = [alpha_t * x_t + (1 - alpha_t) / K] * [alpha_bar_{t-1} * x_0 + (1 - alpha_bar_{t-1}) / K]
# ---> 92 term1 = alpha_t * x_t + (1 - alpha_t) / self.num_classes
#      93 term2 = alpha_bar_t_prev * x_0 + (1 - alpha_bar_t_prev) / self.num_classes
#      95 pi = term1 * term2
#
# File /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/torch/_tensor.py:38, in _handle_torch_function_and_wrap_type_error_to_not_implemented.<locals>.wrapped(self, *args, **kwargs)
#      35 def _handle_torch_function_and_wrap_type_error_to_not_implemented(
#      36     f: Callable[Concatenate[_TensorLike, _P], "Tensor"],
#      37 ) -> Callable[Concatenate[_TensorLike, _P], "Tensor"]:
# ---> 38     @functools.wraps(f)
#      39     def wrapped(self: _TensorLike, *args: _P.args, **kwargs: _P.kwargs) -> "Tensor":
#      40         try:
#      41             # See https://github.com/pytorch/pytorch/issues/75462
#      42             sargs = self, *args
#
# KeyboardInterrupt:

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "shuttle.csv"
output_path = ROOT / "discretized_data" / "shuttle.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "shuttle")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "shuttle" / "tabddpm")

pipeline = TrainTestSplitPipeline(model=TabDDPM)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir
)
print(result)

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "nursery.csv"
output_path = ROOT / "discretized_data" / "nursery.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "nursery")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "nursery" / "tabddpm")

pipeline = TrainTestSplitPipeline(model=TabDDPM)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir
)
print(result)
