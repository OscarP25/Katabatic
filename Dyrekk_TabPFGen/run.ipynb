# %%
# Imports
import sys
from pathlib import Path


# Resolve project root and ensure it's on sys.path
ROOT = Path.cwd().resolve()
for _ in range(5):
    if (ROOT / "pyproject.toml").exists() or (ROOT / "raw_data").exists():
        break
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from katabatic.pipeline.train_test_split.pipeline import TrainTestSplitPipeline
from src.model import TabPFGen
from utils import discretize_preprocess

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "car.csv"
output_path = ROOT / "discretized_data" / "car.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "car")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "car" / "tabpfgen")

pipeline = TrainTestSplitPipeline(model=TabPFGen)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir
)
print(result)
# Out:
# Preprocessing: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/raw_data/car.csv
# Saved preprocessed discrete dataset to: /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/discretized_data/car.csv
# Loaded data with shape: (1728, 7)
# Saved train/test full data
# Train size: (1382, 7), Test size: (346, 7)
# Train label distribution:
#  6
# 2    0.700434
# 0    0.222142
# 1    0.039797
# 3    0.037627
# Name: proportion, dtype: float64
# Test label distribution:
#  6
# 2    0.699422
# 0    0.222543
# 1    0.040462
# 3    0.037572
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (1382, 6) (1382,)
# Test shape: (346, 6) (346,)
# [TabPFGen] Loading data from /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/sample_data/car/train_full.csv...
#
# [TabPFGen] Generating 1382 samples...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 18
#      15 synthetic_dir = str(ROOT / "synthetic" / "car" / "tabpfgen")
#      17 pipeline = TrainTestSplitPipeline(model=TabPFGen)
# ---> 18 result = pipeline.run(
#      19     input_csv=input_csv,
#      20     output_dir=output_dir,
#      21     synthetic_dir=synthetic_dir,
#      22     real_test_dir=real_test_dir
#      23 )
#      24 print(result)
#
# File /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/katabatic/pipeline/train_test_split/pipeline.py:38, in TrainTestSplitPipeline.run(self, *args, **kwargs)
#      35 split_dataset(input_csv, output_dir, *args, **kwargs)
#      37 # Train the model (may consume extra kwargs like 'config')
# ---> 38 current_model.train(output_dir, *args, **kwargs)
#      40 # Filter kwargs for evaluations to avoid unexpected params (e.g., 'config')
#      41 eval_kwargs = dict(kwargs)
#
# File /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/Dyrekk_TabPFGen/src/model.py:137, in TabPFGen.train(self, output_dir, *args, **kwargs)
#     135 # Optional auto-generate synthetic data
#     136 if kwargs.get('auto_generate_synthetic', True) and kwargs.get('synthetic_dir'):
# --> 137     self.sample(
#     138         num_samples=kwargs.get('num_synthetic_samples', len(df)),
#     139         synthetic_dir=kwargs['synthetic_dir']
#     140     )
#     141 return self
#
# File /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/Dyrekk_TabPFGen/src/model.py:218, in TabPFGen.sample(self, num_samples, synthetic_dir)
#     216 # --- Fit TabPFN once ---
#     217 clf = TabPFNClassifier(device="cpu")
# --> 218 clf.fit(self.X_train_processed, self.y_train_encoded)
#     220 # --- SGLD Loop ---
#     221 for step in tqdm(range(self.n_sgld_steps), desc="Sampling (SGLD)"):
#
# File ~/.pyenv/versions/3.11.9/lib/python3.11/contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# File /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/tabpfn_common_utils/telemetry/core/decorators.py:288, in track_model_call.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     286 @functools.wraps(func)
#     287 def wrapper(*args: Any, **kwargs: Any) -> Any:
# --> 288     return _safe_call_with_telemetry(
#     289         func, args, kwargs, model_method, param_names
#     290     )
#
# File /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/tabpfn_common_utils/telemetry/core/decorators.py:332, in _safe_call_with_telemetry(func, args, kwargs, model_method, param_names)
#     330 # Step 2: Run the actual function
#     331 start = time.perf_counter()
# --> 332 result = func(*args, **kwargs)
#     333 duration_ms = int((time.perf_counter() - start) * 1000)
#     335 # Step 3: Send telemetry event
#
# File /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/tabpfn/classifier.py:817, in TabPFNClassifier.fit(self, X, y)
#     815 if not hasattr(self, "models_") or not self.differentiable_input:
#     816     byte_size, rng = self._initialize_model_variables()
# --> 817     ensemble_configs, X, y = self._initialize_dataset_preprocessing(X, y, rng)
#     818 else:  # already fitted and prompt_tuning mode: no cat. features
#     819     _, rng = infer_random_state(self.random_state)
#
# File /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/tabpfn/classifier.py:616, in TabPFNClassifier._initialize_dataset_preprocessing(self, X, y, rng)
#     601 """Internal preprocessing method for input arguments.
#     602 Returns ClassifierEnsembleConfigs, inferred categorical indices,
#     603 and modelfied features X and labels y.
#     604 Sets self.inferred_categorical_indices_.
#     605 """
#     606 X, y, feature_names_in, n_features_in = validate_Xy_fit(
#     607     X,
#     608     y,
#    (...)    613     ignore_pretraining_limits=self.ignore_pretraining_limits,
#     614 )
# --> 616 check_cpu_warning(
#     617     self.devices_, X, allow_cpu_override=self.ignore_pretraining_limits
#     618 )
#     620 if feature_names_in is not None:
#     621     self.feature_names_in_ = feature_names_in
#
# File /mnt/c/Users/DuyPham/OneDrive - Deakin University/Documents/GitHub/Katabatic/.venv/lib/python3.11/site-packages/tabpfn/base.py:410, in check_cpu_warning(devices, X, allow_cpu_override)
#     408 if any(device.type == "cpu" for device in devices):
#     409     if num_samples > 1000:
# --> 410         raise RuntimeError(
#     411             "Running on CPU with more than 1000 samples is not allowed "
#     412             "by default due to slow performance.\n"
#     413             "To override this behavior, set the environment variable "
#     414             "TABPFN_ALLOW_CPU_LARGE_DATASET=1 or "
#     415             "set ignore_pretraining_limits=True.\n"
#     416             "Alternatively, consider using a GPU or the tabpfn-client API: "
#     417             "https://github.com/PriorLabs/tabpfn-client"
#     418         )
#     419     if num_samples > 200:
#     420         warnings.warn(
#     421             "Running on CPU with more than 200 samples may be slow.\n"
#     422             "Consider using a GPU or the tabpfn-client API: "
#     423             "https://github.com/PriorLabs/tabpfn-client",
#     424             stacklevel=2,
#     425         )
#
# RuntimeError: Running on CPU with more than 1000 samples is not allowed by default due to slow performance.
# To override this behavior, set the environment variable TABPFN_ALLOW_CPU_LARGE_DATASET=1 or set ignore_pretraining_limits=True.
# Alternatively, consider using a GPU or the tabpfn-client API: https://github.com/PriorLabs/tabpfn-client

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "adult.csv"
output_path = ROOT / "discretized_data" / "adult.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "adult")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "adult" / "tabpfgen")

pipeline = TrainTestSplitPipeline(model=TabPFGen)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
)
print(result)

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "magic.csv"
output_path = ROOT / "discretized_data" / "magic.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "magic")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "magic" / "tabpfgen")

pipeline = TrainTestSplitPipeline(model=TabPFGen)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
)
print(result)

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "nursery.csv"
output_path = ROOT / "discretized_data" / "nursery.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "nursery")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "nursery" / "tabpfgen")

pipeline = TrainTestSplitPipeline(model=TabPFGen)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir
)
print(result)

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "shuttle.csv"
output_path = ROOT / "discretized_data" / "shuttle.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))

# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "shuttle")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "shuttle" / "tabpfgen")

pipeline = TrainTestSplitPipeline(model=TabPFGen)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir
)
print(result)
