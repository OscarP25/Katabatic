# %%
# Imports
import sys
from pathlib import Path

ROOT = Path(r"C:\Users\Prabu\Downloads\Katabatic").resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

print("ROOT set to:", ROOT)

from katabatic.pipeline.train_test_split.pipeline import TrainTestSplitPipeline
from utils import discretize_preprocess

from katabatic.models.ctgan.models import CTGANModel
# Out:
# ROOT set to: C:\Users\Prabu\Downloads\Katabatic

# %%
# Preprocess data
dataset_path = ROOT / "raw_data" / "shuttle.csv"
output_path = ROOT / "discretized_data" / "shuttle.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))
# Out:
# Preprocessing: C:\Users\Prabu\Downloads\Katabatic\raw_data\shuttle.csv
# Saved preprocessed discrete dataset to: C:\Users\Prabu\Downloads\Katabatic\discretized_data\shuttle.csv

# %%
 #Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "shuttle")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "shuttle" / "ctgan")

model = CTGANModel(epochs=100)
print("CTGAN will train for:", model.cfg["epochs"], "epochs")

pipeline = TrainTestSplitPipeline(model=CTGANModel)

result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
)

print(result)
# Out:
# CTGAN will train for: 100 epochs
# Loaded data with shape: (58000, 10)
# Saved train/test full data
# Train size: (46400, 10), Test size: (11600, 10)
# Train label distribution:
#  class
# 0    0.785970
# 3    0.153491
# 4    0.056336
# 2    0.002953
# 1    0.000862
# 6    0.000216
# 5    0.000172
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.785948
# 3    0.153534
# 4    0.056293
# 2    0.002931
# 1    0.000862
# 6    0.000259
# 5    0.000172
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (46400, 9) (46400,)
# Test shape: (11600, 9) (11600,)
# [CTGAN] Synthetic data saved:
#   X -> C:\Users\Prabu\Downloads\Katabatic\synthetic\shuttle\ctgan\x_synth.csv
#   y -> C:\Users\Prabu\Downloads\Katabatic\synthetic\shuttle\ctgan\y_synth.csv
# C:\Users\Prabu\AppData\Local\pypoetry\Cache\virtualenvs\katabatic-AJr3_ocI-py3.11\Lib\site-packages\xgboost\training.py:199: UserWarning: [01:44:03] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Results saved to: Results\shuttle\ctgan_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.7859
# F1 Score: 0.6917
#
# MLP:
# Accuracy: 0.7859
# F1 Score: 0.6923
#
# RF:
# Accuracy: 0.7516
# F1 Score: 0.6787
#
# XGBoost:
# Accuracy: 0.7992
# F1 Score: 0.7253
# Train test split pipeline executed successfully.
