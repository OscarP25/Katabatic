# %%
import sys
from pathlib import Path

ROOT = Path(r"C:\Users\Prabu\Downloads\Katabatic").resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

print("ROOT set to:", ROOT)

from katabatic.pipeline.train_test_split.pipeline import TrainTestSplitPipeline
from utils import discretize_preprocess

from katabatic.models.tabddpm.models import Tabddpm
# Out:
# ROOT set to: C:\Users\Prabu\Downloads\Katabatic

# %%
# Preprocess data
dataset_path = ROOT / "raw_data" / "magic.csv"         
output_path = ROOT / "discretized_data" / "magic.csv"  

output_path.parent.mkdir(parents=True, exist_ok=True)

# Preprocess
discretize_preprocess(str(dataset_path), str(output_path))
# Out:
# Preprocessing: C:\Users\Prabu\Downloads\Katabatic\raw_data\magic.csv
# Saved preprocessed discrete dataset to: C:\Users\Prabu\Downloads\Katabatic\discretized_data\magic.csv

# %%
import warnings
from sklearn.exceptions import ConvergenceWarning

warnings.filterwarnings("ignore", category=ConvergenceWarning)         
warnings.filterwarnings("ignore", message="Parameters: {")           
warnings.filterwarnings("ignore", category=UserWarning, module="xgboost")
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "magic")
real_test_dir = output_dir
synthetic_dir = str(ROOT / "synthetic" / "magic" / "tabddpm")

class TabDDPMFull(Tabddpm):
    def train(self, *args, **kwargs):
       
        config = kwargs.get("config") or {}
        if not isinstance(config, dict):
            config = {}

      
        config["steps"] = 1500

        # Pass updated config into the original train()
        kwargs["config"] = config
        return super().train(*args, **kwargs)

pipeline = TrainTestSplitPipeline(
    model=lambda: TabDDPMFull()
)

result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
)

print(result)
# Out:
# Loaded data with shape: (19020, 11)
# Saved train/test full data
# Train size: (15216, 11), Test size: (3804, 11)
# Train label distribution:
#  class
# 0    0.648396
# 1    0.351604
# Name: proportion, dtype: float64
# Test label distribution:
#  class
# 0    0.648265
# 1    0.351735
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (15216, 10) (15216,)
# Test shape: (3804, 10) (3804,)
# Step 100/1500 | MLoss: 0.0000 | GLoss: 0.3943
# Step 200/1500 | MLoss: 0.0000 | GLoss: 0.0272
# Step 300/1500 | MLoss: 0.0000 | GLoss: 0.0061
# Step 400/1500 | MLoss: 0.0000 | GLoss: 0.0050
# Step 500/1500 | MLoss: 0.0000 | GLoss: 0.0056
# Step 600/1500 | MLoss: 0.0000 | GLoss: 0.0038
# Step 700/1500 | MLoss: 0.0000 | GLoss: 0.0058
# Step 800/1500 | MLoss: 0.0000 | GLoss: 0.0111
# Step 900/1500 | MLoss: 0.0000 | GLoss: 0.0045
# Step 1000/1500 | MLoss: 0.0000 | GLoss: 0.0074
# Step 1100/1500 | MLoss: 0.0000 | GLoss: 0.0024
# Step 1200/1500 | MLoss: 0.0000 | GLoss: 0.0020
# Step 1300/1500 | MLoss: 0.0000 | GLoss: 0.0038
# Step 1400/1500 | MLoss: 0.0000 | GLoss: 0.0027
# Step 1500/1500 | MLoss: 0.0000 | GLoss: 0.0091
#
# Results saved to: Results\magic\tabddpm_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.6485
# F1 Score: 0.5105
# AUC: 0.2916
#
# MLP:
# Accuracy: 0.4566
# F1 Score: 0.4635
# AUC: 0.4121
#
# RF:
# Accuracy: 0.5011
# F1 Score: 0.4667
# AUC: 0.4104
#
# XGBoost:
# Accuracy: 0.6667
# F1 Score: 0.5511
# AUC: 0.6825
# Train test split pipeline executed successfully.
