# %%
# Imports
import sys
from pathlib import Path

# Resolve project root and ensure it's on sys.path
ROOT = Path(r"C:\Users\Prabu\Downloads\Katabatic").resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

print("ROOT set to:", ROOT)

from katabatic.pipeline.train_test_split.pipeline import TrainTestSplitPipeline
from utils import discretize_preprocess
from katabatic.models.medgan.models import MEDGAN
# Out:
# ROOT set to: C:\Users\Prabu\Downloads\Katabatic

# %%
# Preprocess data
from pathlib import Path

dataset_path = ROOT / "raw_data" / "car.csv"
output_path = ROOT / "discretized_data" / "car.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

discretize_preprocess(str(dataset_path), str(output_path))
# Out:
# Preprocessing: C:\Users\Prabu\Downloads\Katabatic\raw_data\car.csv
# Saved preprocessed discrete dataset to: C:\Users\Prabu\Downloads\Katabatic\discretized_data\car.csv

# %%
# Run pipeline
input_csv = str(output_path)
output_dir = str(ROOT / "sample_data" / "car")
real_test_dir = output_dir

synthetic_dir = str(ROOT / "synthetic" / "car" / "medgan")

pipeline = TrainTestSplitPipeline(model=MEDGAN)
result = pipeline.run(
    input_csv=input_csv,
    output_dir=output_dir,
    synthetic_dir=synthetic_dir,
    real_test_dir=real_test_dir,
)
print(result)
# Out:
# INFO:katabatic.models.medgan.models:================================================================================
# INFO:katabatic.models.medgan.models:Training MedGAN Model
# INFO:katabatic.models.medgan.models:================================================================================
# INFO:katabatic.models.medgan.models:Loaded training data: (1382, 6)
# INFO:katabatic.models.medgan.models:Data normalized to [0, 1] range
# INFO:katabatic.models.medgan.models:Original range: [0.00, 3.00]
# INFO:katabatic.models.medgan.models:Normalized range: [0.00, 1.00]
# INFO:katabatic.models.medgan.models:
# Phase 1: Pretraining Autoencoder for 150 epochs...
# Loaded data with shape: (1728, 7)
# Saved train/test full data
# Train size: (1382, 7), Test size: (346, 7)
# Train label distribution:
#  6
# 2    0.700434
# 0    0.222142
# 1    0.039797
# 3    0.037627
# Name: proportion, dtype: float64
# Test label distribution:
#  6
# 2    0.699422
# 0    0.222543
# 1    0.040462
# 3    0.037572
# Name: proportion, dtype: float64
# Saved X/y split
# Training shape: (1382, 6) (1382,)
# Test shape: (346, 6) (346,)
# INFO:katabatic.models.medgan.models:Epoch 1/150: AE Loss = 0.557409
# INFO:katabatic.models.medgan.models:Epoch 10/150: AE Loss = 0.336443
# INFO:katabatic.models.medgan.models:Epoch 20/150: AE Loss = 0.325516
# INFO:katabatic.models.medgan.models:Epoch 30/150: AE Loss = 0.322229
# INFO:katabatic.models.medgan.models:Epoch 40/150: AE Loss = 0.321299
# INFO:katabatic.models.medgan.models:Epoch 50/150: AE Loss = 0.321980
# INFO:katabatic.models.medgan.models:Epoch 60/150: AE Loss = 0.324729
# INFO:katabatic.models.medgan.models:Epoch 70/150: AE Loss = 0.320665
# INFO:katabatic.models.medgan.models:Epoch 80/150: AE Loss = 0.322037
# INFO:katabatic.models.medgan.models:Epoch 90/150: AE Loss = 0.319870
# INFO:katabatic.models.medgan.models:Epoch 100/150: AE Loss = 0.318878
# INFO:katabatic.models.medgan.models:Epoch 110/150: AE Loss = 0.317609
# INFO:katabatic.models.medgan.models:Epoch 120/150: AE Loss = 0.316520
# INFO:katabatic.models.medgan.models:Epoch 130/150: AE Loss = 0.317534
# INFO:katabatic.models.medgan.models:Epoch 140/150: AE Loss = 0.313000
# INFO:katabatic.models.medgan.models:Epoch 150/150: AE Loss = 0.313043
# INFO:katabatic.models.medgan.models:
# Phase 2: Training GAN for 1500 epochs...
# INFO:katabatic.models.medgan.models:Epoch 1/1500: D Loss = 1.330679, G Loss = 0.676852
# INFO:katabatic.models.medgan.models:Epoch 100/1500: D Loss = 0.040806, G Loss = 4.845420
# INFO:katabatic.models.medgan.models:Epoch 200/1500: D Loss = 0.170935, G Loss = 4.021826
# INFO:katabatic.models.medgan.models:Epoch 300/1500: D Loss = 0.382761, G Loss = 3.592218
# INFO:katabatic.models.medgan.models:Epoch 400/1500: D Loss = 0.326488, G Loss = 3.924876
# INFO:katabatic.models.medgan.models:Epoch 500/1500: D Loss = 0.995861, G Loss = 1.990531
# INFO:katabatic.models.medgan.models:Epoch 600/1500: D Loss = 0.751081, G Loss = 1.899104
# INFO:katabatic.models.medgan.models:Epoch 700/1500: D Loss = 0.649279, G Loss = 2.206368
# INFO:katabatic.models.medgan.models:Epoch 800/1500: D Loss = 0.785191, G Loss = 2.295439
# INFO:katabatic.models.medgan.models:Epoch 900/1500: D Loss = 0.771031, G Loss = 2.091376
# INFO:katabatic.models.medgan.models:Epoch 1000/1500: D Loss = 0.731058, G Loss = 1.943631
# INFO:katabatic.models.medgan.models:Epoch 1100/1500: D Loss = 0.756085, G Loss = 2.020969
# INFO:katabatic.models.medgan.models:Epoch 1200/1500: D Loss = 0.795119, G Loss = 1.932096
# INFO:katabatic.models.medgan.models:Epoch 1300/1500: D Loss = 0.608129, G Loss = 2.177935
# INFO:katabatic.models.medgan.models:Epoch 1400/1500: D Loss = 0.612901, G Loss = 2.245055
# INFO:katabatic.models.medgan.models:Epoch 1500/1500: D Loss = 0.687136, G Loss = 2.341683
# INFO:katabatic.models.medgan.models:
# Generating 1382 synthetic samples...
# INFO:katabatic.models.medgan.models:
# Synthetic data saved to: C:\Users\Prabu\Downloads\Katabatic\synthetic\car\medgan
# INFO:katabatic.models.medgan.models:Training complete!
# C:\Users\Prabu\AppData\Local\pypoetry\Cache\virtualenvs\katabatic-AJr3_ocI-py3.11\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:780: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Prabu\AppData\Local\pypoetry\Cache\virtualenvs\katabatic-AJr3_ocI-py3.11\Lib\site-packages\xgboost\training.py:199: UserWarning: [00:38:15] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "scale_pos_weight" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Results saved to: Results\car\medgan_tstr.csv
#
# TSTR Evaluation Results:
#
# LR:
# Accuracy: 0.7168
# F1 Score: 0.6270
#
# MLP:
# Accuracy: 0.7457
# F1 Score: 0.7064
#
# RF:
# Accuracy: 0.7486
# F1 Score: 0.7234
#
# XGBoost:
# Accuracy: 0.7197
# F1 Score: 0.7110
# Train test split pipeline executed successfully.
